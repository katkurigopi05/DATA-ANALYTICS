# %% [markdown]
# # Web Scraping Lecture Part 2 --- JSON APIs
#
# ## Content
# 5. Interacting with JSON APIs
# 6. Interacting with other type of APIs
# 7. Preparing for Project : Job Data Scraping

# %% [markdown]
# # 5. Interacting with JSON API
#
#
# ## What is API?
#
# API stands for “Application Programming Interface.” It is an interface or communication protocol between a client and a server intended to simplify the building of client-side software. It has been described as a “contract” between the client and the server, such that if the client makes a request in a specific format, it will always get a response in a specific format or initiate a defined action. An API may be for a web-based system, operating system, database system, computer hardware, or software library.(Wiki)
#
# Many websites have public APIs providing data feeds via JSON or some other formats.
#
# ## JSON Data Introduction
#
# JSON short for JavaScript Object Notation, has become one of the standard formats for sending data by HTTP request between web browers and other applications. It is a much more free-form data format than a tabular text form like CSV.
#
# For exmaple, this website shows the last 30 GitHub issues for pandas, https://api.github.com/repos/pandas-dev/pandas/issues. We call it is an API, and the data format is in JSON. Most web APIs return to JSON or xml format.
#
# Another example of JSON:
#
#     {"ticker":"AAPL:US","return_code":0,"ttl":300,"disp_name":"Apple Inc","last_price":222.11,"price_precision":3.0,"time_of_last_updt":"2018-10-12","pct_chge_1D":3.57192993}
#
# It is a much more free-form data format than a tabular text form like CSV.
#
# Sometimes people see json as nested dictionary in python.
#
# **json library**
#
# There are several python libraries for reading and writing JSON data. *json* is one of those. To convert a JSON string to Python form, we use *json.loads*.

# %%
#Define a json string. 
obj="""
{"name":"Wes",
 "places_lived":["United States","Spain","China"],
 "siblings":[{"name":"Scott","age":30,"pets":["Zeus","Zuko"]},
             {"name":"Katie","age":38,"pets":["Sixes","Cisco"]}]
}
"""
obj
# Out:
# '\n{"name":"Wes",\n "places_lived":["United States","Spain","China"],\n "siblings":[{"name":"Scott","age":30,"pets":["Zeus","Zuko"]},\n             {"name":"Katie","age":38,"pets":["Sixes","Cisco"]}]\n}\n'

# %%
import json
result=json.loads(obj) # json.loads() convert a json string to python dictionary.
result
#result can be treated as a dictionary in python.
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'China'],
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Cisco']}]}

# %%
result['siblings']
# Out:
# [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#  {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Cisco']}]

# %%
result['siblings'][0]
# Out:
# {'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']}

# %%
result['siblings'][0]['pets']
# Out:
# ['Zeus', 'Zuko']

# %%
result['siblings'][0]['pets'][0]
# Out:
# 'Zeus'

# %%
#converts a python object back to JSON string. 
asjon=json.dumps(result)
asjon
# Out:
# '{"name": "Wes", "places_lived": ["United States", "Spain", "China"], "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]}, {"name": "Katie", "age": 38, "pets": ["Sixes", "Cisco"]}]}'

# %%
import pandas as pd
siblings=pd.DataFrame(result['places_lived'])
siblings
# Out:
#                0
# 0  United States
# 1          Spain
# 2          China

# %%
siblings=pd.DataFrame(result["siblings"])
siblings
# Out:
#     name  age            pets
# 0  Scott   30    [Zeus, Zuko]
# 1  Katie   38  [Sixes, Cisco]

# %%
siblings=pd.DataFrame(result["siblings"][0])
siblings
# Out:
#     name  age  pets
# 0  Scott   30  Zeus
# 1  Scott   30  Zuko

# %%
siblings=pd.DataFrame(result["siblings"][0]['pets'])
siblings
# Out:
#       0
# 0  Zeus
# 1  Zuko

# %% [markdown]
# ## <font color='red'>**Exercise: Access the nested key ‘salary’ from the following JSON**</font>
#
# write code to print the value of salary
#
# expected output:
#
# 7000

# %%
import json

sampleJson = """{ 
   "company":{ 
      "employee":{ 
         "name":"emma",
         "payble":{ 
            "salary":7000,
            "bonus":800
         }
      }
   }
}"""

# %% [markdown]
# ## <font color='red'>**Exercise:**</font>
# Parse the following JSON to get all the values of a key ‘name’ within an array
#
# Expected output:
#
# ["name1", "name2"]

# %%
[ 
   { 
      "id":1,
      "name":"name1",
      "color":[ 
         "red",
         "green"
      ]
   },
   { 
      "id":2,
      "name":"name2",
      "color":[ 
         "pink",
         "yellow"
      ]
   }
]
# Out:
# [{'id': 1, 'name': 'name1', 'color': ['red', 'green']},
#  {'id': 2, 'name': 'name2', 'color': ['pink', 'yellow']}]

# %% [markdown]
# ## Scraping JSON using requests lib
# One easy-to-use method to access APIs from python is the **requests** package. The requests library will make a **GET** request to a web server, which will download the HTML contents of a given web page for us. There are several different types of requests we can make using requests, of which GET is just one.
#
# To find the last 30 GitHub issues for pandas on GitHub, we make a **GET HTTP** request.

# %%
import requests
url='https://api.github.com/repos/pandas-dev/pandas/issues'
resp=requests.get(url)#When you ping a website or portal for information this is called making a request. 
                       #That is exactly what the Requests library has been designed to do.
resp # resp is a Response object.
# Out:
# <Response [200]>

# %% [markdown]
# After running our request, we get a Response object. This object has a status_code property, which indicates if the page was downloaded successfully.
#
# A status_code of 200 means that the page downloaded successfully. We won’t fully dive into status codes here, but a status code starting with a 2 generally indicates success, and a code starting with a 4 or a 5 indicates an error.

# %%
data=resp.json()# Response object's json method will return to a dictionary 
                # containing JSON parsed into native python objects. 
len(data)
# each element in data is a dictionary containing all the data found on a GitHub issue page.
# Out:
# 30

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61173',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61173/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61173/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61173/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61173',
#   'id': 2942576054,
#   'node_id': 'PR_kwDOAA0YD86P1abm',
#   'number': 61173,
#   'title': 'BUG: Handle line and bar on the same plot',
#   'user': {'login': 'MartinBraquet',
#    'id': 25173236,
#    'node_id': 'MDQ6VXNlcjI1MTczMjM2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25173236?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MartinBraquet',
#    'html_url': 'https://github.com/MartinBraquet',
#    'followers_url': 'https://api.github.com/users/MartinBraquet/followers',
#    'following_url': 'https://api.github.com/users/MartinBraquet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MartinBraquet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MartinBraquet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MartinBraquet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MartinBraquet/orgs',
#    'repos_url': 'https://api.github.com/users/MartinBraquet/repos',
#    'events_url': 'https://api.github.com/users/MartinBraquet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MartinBraquet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-03-24T09:22:19Z',
#   'updated_at': '2025-03-24T10:51:17Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61173',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61173',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61173.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61173.patch',
#    'merged_at': None},
#   'body': "- [x] closes #61161\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nPlease provide feedback on the overall approach. Once confirmed, I'll expand and cover with tests.\r\n",
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61173/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61173/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61172',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61172/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61172/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61172/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61172',
#   'id': 2941851698,
#   'node_id': 'I_kwDOAA0YD86vWRgy',
#   'number': 61172,
#   'title': 'BUG: pd.read_csv() on empty files should give an empty dataframe pd.DataFrame()',
#   'user': {'login': 'xuancong84',
#    'id': 10172392,
#    'node_id': 'MDQ6VXNlcjEwMTcyMzky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10172392?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xuancong84',
#    'html_url': 'https://github.com/xuancong84',
#    'followers_url': 'https://api.github.com/users/xuancong84/followers',
#    'following_url': 'https://api.github.com/users/xuancong84/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/xuancong84/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/xuancong84/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/xuancong84/subscriptions',
#    'organizations_url': 'https://api.github.com/users/xuancong84/orgs',
#    'repos_url': 'https://api.github.com/users/xuancong84/repos',
#    'events_url': 'https://api.github.com/users/xuancong84/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/xuancong84/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_csv, to_csv'},
#    {'id': 2365504893,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0ODkz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Closing%20Candidate',
#     'name': 'Closing Candidate',
#     'color': 'be21f2',
#     'default': False,
#     'description': 'May be closeable, needs more eyeballs'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'MartinBraquet',
#    'id': 25173236,
#    'node_id': 'MDQ6VXNlcjI1MTczMjM2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25173236?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MartinBraquet',
#    'html_url': 'https://github.com/MartinBraquet',
#    'followers_url': 'https://api.github.com/users/MartinBraquet/followers',
#    'following_url': 'https://api.github.com/users/MartinBraquet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MartinBraquet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MartinBraquet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MartinBraquet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MartinBraquet/orgs',
#    'repos_url': 'https://api.github.com/users/MartinBraquet/repos',
#    'events_url': 'https://api.github.com/users/MartinBraquet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MartinBraquet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'assignees': [{'login': 'MartinBraquet',
#     'id': 25173236,
#     'node_id': 'MDQ6VXNlcjI1MTczMjM2',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/25173236?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/MartinBraquet',
#     'html_url': 'https://github.com/MartinBraquet',
#     'followers_url': 'https://api.github.com/users/MartinBraquet/followers',
#     'following_url': 'https://api.github.com/users/MartinBraquet/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/MartinBraquet/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/MartinBraquet/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/MartinBraquet/subscriptions',
#     'organizations_url': 'https://api.github.com/users/MartinBraquet/orgs',
#     'repos_url': 'https://api.github.com/users/MartinBraquet/repos',
#     'events_url': 'https://api.github.com/users/MartinBraquet/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/MartinBraquet/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-03-24T03:07:45Z',
#   'updated_at': '2025-03-24T20:51:16Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [x] I have checked that this issue has not already been reported.\n\n- [x] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [x] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nUsing `pd.read_csv()` to open an empty CSV file (0-bytes file or single-byte file (EOL character) by VIM) will give the following error:\n\nTraceback (most recent call last):\n  File "<stdin>", line 1, in <module>\n  File "/home/xuancong/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py", line 1026, in read_csv\n    return _read(filepath_or_buffer, kwds)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/xuancong/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py", line 620, in _read\n    parser = TextFileReader(filepath_or_buffer, **kwds)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/xuancong/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py", line 1620, in __init__\n    self._engine = self._make_engine(f, self.engine)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/xuancong/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py", line 1898, in _make_engine\n    return mapping[engine](f, **self.options)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/xuancong/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py", line 93, in __init__\n    self._reader = parsers.TextReader(src, **kwds)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "parsers.pyx", line 581, in pandas._libs.parsers.TextReader.__cinit__\npandas.errors.EmptyDataError: No columns to parse from file\n```\n\n### Issue Description\n\nThe reason of the crash is that there is no columns to parse. However, Pandas does allow dataframes with no columns and no rows, i.e., `pd.DataFrame()` gives an empty DataFrame with no rows and no columns.\n\nThe logic reasoning is that if opening an empty CSV will cause crash, then **opening what kind of CSV file will give rise to an empty DataFrame**? When designing APIs, one fundamental principle is to try to keep a 1-to-1 mapping between input and output (so as to reduce information loss); thus, in this case, it is the mapping between CSV file and dataframe. I do agree that if the CSV does not exist or cannot be read (due to permission), then the call should crash. But if the CSV file is empty, `pd.read_csv()` should give an empty dataframe because empty dataframe does exist. Otherwise, what text should I put into a CSV file so that `pd.read_csv()` will give an empty DataFrame, i.e., `pd.DataFrame()`? Thanks!\n\n### Expected Behavior\n\nOpening an empty CSV file should give an empty DataFrame (i.e., pd.DataFrame()):\n```\nEmpty DataFrame\nColumns: []\nIndex: []\n```\n\n### Installed Versions\n\n<details>\n\nINSTALLED VERSIONS\n------------------\ncommit                : 0691c5cf90477d3503834d983f69350f250a6ff7\npython                : 3.11.5\npython-bits           : 64\nOS                    : Linux\nOS-release            : 6.8.0-52-generic\nVersion               : #53~22.04.1-Ubuntu SMP PREEMPT_DYNAMIC Wed Jan 15 19:18:46 UTC 2\nmachine               : x86_64\nprocessor             : x86_64\nbyteorder             : little\nLC_ALL                : en_US.UTF-8\nLANG                  : en_US.UTF-8\nLOCALE                : en_US.UTF-8\n\npandas                : 2.2.3\nnumpy                 : 1.26.4\npytz                  : 2023.3.post1\ndateutil              : 2.8.2\npip                   : 25.0.1\nCython                : None\nsphinx                : 5.0.2\nIPython               : 8.15.0\nadbc-driver-postgresql: None\nadbc-driver-sqlite    : None\nbs4                   : 4.12.2\nblosc                 : None\nbot ...
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61172/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61172/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61171',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61171/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61171/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61171/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61171',
#   'id': 2941462140,
#   'node_id': 'PR_kwDOAA0YD86Pxsxt',
#   'number': 61171,
#   'title': 'DataFrame.dtypes.to_json OverflowError: Maximum recursion level reached',
#   'user': {'login': 'Aliebc',
#    'id': 89406058,
#    'node_id': 'MDQ6VXNlcjg5NDA2MDU4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89406058?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Aliebc',
#    'html_url': 'https://github.com/Aliebc',
#    'followers_url': 'https://api.github.com/users/Aliebc/followers',
#    'following_url': 'https://api.github.com/users/Aliebc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Aliebc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Aliebc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Aliebc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Aliebc/orgs',
#    'repos_url': 'https://api.github.com/users/Aliebc/repos',
#    'events_url': 'https://api.github.com/users/Aliebc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Aliebc/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-03-23T20:16:22Z',
#   'updated_at': '2025-03-24T20:06:28Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61171',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61171',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61171.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61171.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #61170  (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61171/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61171/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61170',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61170/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61170/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61170/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61170',
#   'id': 2941455212,
#   'node_id': 'I_kwDOAA0YD86vUwts',
#   'number': 61170,
#   'title': 'BUG: DataFrame.dtypes.to_json OverflowError: Maximum recursion level reached',
#   'user': {'login': 'Aliebc',
#    'id': 89406058,
#    'node_id': 'MDQ6VXNlcjg5NDA2MDU4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89406058?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Aliebc',
#    'html_url': 'https://github.com/Aliebc',
#    'followers_url': 'https://api.github.com/users/Aliebc/followers',
#    'following_url': 'https://api.github.com/users/Aliebc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Aliebc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Aliebc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Aliebc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Aliebc/orgs',
#    'repos_url': 'https://api.github.com/users/Aliebc/repos',
#    'events_url': 'https://api.github.com/users/Aliebc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Aliebc/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 49379259,
#     'node_id': 'MDU6TGFiZWw0OTM3OTI1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20JSON',
#     'name': 'IO JSON',
#     'color': '207de5',
#     'default': False,
#     'description': 'read_json, to_json, json_normalize'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'GalkaKG',
#    'id': 103485495,
#    'node_id': 'U_kgDOBisQNw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103485495?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GalkaKG',
#    'html_url': 'https://github.com/GalkaKG',
#    'followers_url': 'https://api.github.com/users/GalkaKG/followers',
#    'following_url': 'https://api.github.com/users/GalkaKG/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/GalkaKG/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/GalkaKG/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/GalkaKG/subscriptions',
#    'organizations_url': 'https://api.github.com/users/GalkaKG/orgs',
#    'repos_url': 'https://api.github.com/users/GalkaKG/repos',
#    'events_url': 'https://api.github.com/users/GalkaKG/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/GalkaKG/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'assignees': [{'login': 'GalkaKG',
#     'id': 103485495,
#     'node_id': 'U_kgDOBisQNw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/103485495?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/GalkaKG',
#     'html_url': 'https://github.com/GalkaKG',
#     'followers_url': 'https://api.github.com/users/GalkaKG/followers',
#     'following_url': 'https://api.github.com/users/GalkaKG/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/GalkaKG/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/GalkaKG/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/GalkaKG/subscriptions',
#     'organizations_url': 'https://api.github.com/users/GalkaKG/orgs',
#     'repos_url': 'https://api.github.com/users/GalkaKG/repos',
#     'events_url': 'https://api.github.com/users/GalkaKG/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/GalkaKG/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2025-03-23T20:08:19Z',
#   'updated_at': '2025-03-24T13:11:45Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [x] I have checked that this issue has not already been reported.\n\n- [x] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [x] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\nfrom io import StringIO\n\ndf = pd.DataFrame({\'A\': [1, 2, 3], \'B\': [4, 5, 6]})\n\ndts = df.dtypes\nprint(dts)\n\n# dts to csv\n# Expected: A,int64\\nB,int64\\n No error\ntest_csv = StringIO()\ndts.to_csv(test_csv)\nprint(test_csv.getvalue())\n\n# dts to json\n# Expected: {"A": "int64", "B": "int64"} No error\nprint(dts.to_json())\n# OverflowError: Maximum recursion level reached\n```\n\n### Issue Description\n\nWhen calling `to_csv()` on a `pd.Series` of `dtypes`, it works without error and outputs as expected. However, calling `to_json()` on the same `Series` raises an `OverflowError: Maximum recursion level reached`.\n\n### Expected Behavior\n\nExpected: {"A": "int64", "B": "int64"} without error\n\n### Installed Versions\n\nINSTALLED VERSIONS\n------------------\ncommit                : d9cdd2ee5a58015ef6f4d15c7226110c9aab8140\npython                : 3.11.11.final.0\npython-bits           : 64\nOS                    : Darwin\nOS-release            : 24.3.0\nVersion               : Darwin Kernel Version 24.3.0: Thu Jan  2 20:24:23 PST 2025; root:xnu-11215.81.4~3/RELEASE_ARM64_T6020\nmachine               : arm64\nprocessor             : arm\nbyteorder             : little\nLC_ALL                : None\nLANG                  : zh_CN.UTF-8\nLOCALE                : zh_CN.UTF-8\n\npandas                : 2.2.2\nnumpy                 : 1.26.4\npytz                  : 2022.6\ndateutil              : 2.8.2\nsetuptools            : 75.6.0\npip                   : 24.3.1\nCython                : None\npytest                : 8.2.2\nhypothesis            : None\nsphinx                : None\nblosc                 : None\nfeather               : None\nxlsxwriter            : None\nlxml.etree            : 4.9.3\nhtml5lib              : 1.1\npymysql               : None\npsycopg2              : None\njinja2                : 3.1.2\nIPython               : 8.11.0\npandas_datareader     : None\nadbc-driver-postgresql: None\nadbc-driver-sqlite    : None\nbs4                   : 4.12.2\nbottleneck            : None\ndataframe-api-compat  : None\nfastparquet           : None\nfsspec                : 2023.12.2\ngcsfs                 : None\nmatplotlib            : 3.8.3\nnumba                 : 0.58.1\nnumexpr               : None\nodfpy                 : None\nopenpyxl              : 3.1.2\npandas_gbq            : None\npyarrow               : 14.0.1\npyreadstat            : None\npython-calamine       : None\npyxlsb                : None\ns3fs                  : None\nscipy                 : 1.12.0\nsqlalchemy            : None\ntables                : None\ntabulate              : None\nxarray                : None\nxlrd                  : 2.0.1\nzstandard             : None\ntzdata                : 2024.1\nqtpy                  : None\npyqt5                 : None\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61170/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61170/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61168',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61168/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61168/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61168/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61168',
#   'id': 2941184864,
#   'node_id': 'PR_kwDOAA0YD86Pw0Ry',
#   'number': 61168,
#   'title': 'ENH: Accept no fields for groupby by',
#   'user': {'login': 'udit710',
#    'id': 103230240,
#    'node_id': 'U_kgDOBicrIA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103230240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/udit710',
#    'html_url': 'https://github.com/udit710',
#    'followers_url': 'https://api.github.com/users/udit710/followers',
#    'following_url': 'https://api.github.com/users/udit710/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/udit710/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/udit710/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/udit710/subscriptions',
#    'organizations_url': 'https://api.github.com/users/udit710/orgs',
#    'repos_url': 'https://api.github.com/users/udit710/repos',
#    'events_url': 'https://api.github.com/users/udit710/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/udit710/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2025-03-23T13:21:20Z',
#   'updated_at': '2025-03-24T05:50:04Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61168',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61168',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61168.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61168.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #61160 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61168/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61168/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61166',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61166/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61166/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61166/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61166',
#   'id': 2940295236,
#   'node_id': 'I_kwDOAA0YD86vQVhE',
#   'number': 61166,
#   'title': 'ENH: Enable nsmallest/nlargest on object dtype',
#   'user': {'login': 'Gri72',
#    'id': 61454390,
#    'node_id': 'MDQ6VXNlcjYxNDU0Mzkw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61454390?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Gri72',
#    'html_url': 'https://github.com/Gri72',
#    'followers_url': 'https://api.github.com/users/Gri72/followers',
#    'following_url': 'https://api.github.com/users/Gri72/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Gri72/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Gri72/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Gri72/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Gri72/orgs',
#    'repos_url': 'https://api.github.com/users/Gri72/repos',
#    'events_url': 'https://api.github.com/users/Gri72/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Gri72/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 5432590063,
#     'node_id': 'LA_kwDOAA0YD88AAAABQ86-7w',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Filters',
#     'name': 'Filters',
#     'color': '8EFC7E',
#     'default': False,
#     'description': 'e.g. head, tail, nth'},
#    {'id': 6323552771,
#     'node_id': 'LA_kwDOAA0YD88AAAABeOnCAw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Sorting',
#     'name': 'Sorting',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'e.g. sort_index, sort_values'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'RutujaGhodake',
#    'id': 135499591,
#    'node_id': 'U_kgDOCBOPRw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/135499591?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RutujaGhodake',
#    'html_url': 'https://github.com/RutujaGhodake',
#    'followers_url': 'https://api.github.com/users/RutujaGhodake/followers',
#    'following_url': 'https://api.github.com/users/RutujaGhodake/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/RutujaGhodake/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/RutujaGhodake/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/RutujaGhodake/subscriptions',
#    'organizations_url': 'https://api.github.com/users/RutujaGhodake/orgs',
#    'repos_url': 'https://api.github.com/users/RutujaGhodake/repos',
#    'events_url': 'https://api.github.com/users/RutujaGhodake/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/RutujaGhodake/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'assignees': [{'login': 'RutujaGhodake',
#     'id': 135499591,
#     'node_id': 'U_kgDOCBOPRw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/135499591?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/RutujaGhodake',
#     'html_url': 'https://github.com/RutujaGhodake',
#     'followers_url': 'https://api.github.com/users/RutujaGhodake/followers',
#     'following_url': 'https://api.github.com/users/RutujaGhodake/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/RutujaGhodake/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/RutujaGhodake/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/RutujaGhodake/subscriptions',
#     'organizations_url': 'https://api.github.com/users/RutujaGhodake/orgs',
#     'repos_url': 'https://api.github.com/users/RutujaGhodake/repos',
#     'events_url': 'https://api.github.com/users/RutujaGhodake/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/RutujaGhodake/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2025-03-22T10:36:03Z',
#   'updated_at': '2025-03-24T06:18:00Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'body': 'Is it possible to implement method DataFrame.nsorted that equivalent to `df.sort_values(by=["col1", "col2"], ascending=[True, False]).head(k)`, but with time complexity O(n log k)? I know about `nlargest` and `nsmallest` methods but unfortunately they work only with numeric columns.\n\nExample:\n```python\ndf.nsorted(k=6, by=["col1", "col2"], ascending=[True, False])\n```',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61166/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61166/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61164',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61164/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61164/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61164/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61164',
#   'id': 2939534423,
#   'node_id': 'I_kwDOAA0YD86vNbxX',
#   'number': 61164,
#   'title': 'ENH: merge_asof threshold minimum',
#   'user': {'login': 'Lituchy',
#    'id': 41648348,
#    'node_id': 'MDQ6VXNlcjQxNjQ4MzQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41648348?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Lituchy',
#    'html_url': 'https://github.com/Lituchy',
#    'followers_url': 'https://api.github.com/users/Lituchy/followers',
#    'following_url': 'https://api.github.com/users/Lituchy/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Lituchy/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Lituchy/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Lituchy/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Lituchy/orgs',
#    'repos_url': 'https://api.github.com/users/Lituchy/repos',
#    'events_url': 'https://api.github.com/users/Lituchy/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Lituchy/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'},
#    {'id': 219960758,
#     'node_id': 'MDU6TGFiZWwyMTk5NjA3NTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Discussion',
#     'name': 'Needs Discussion',
#     'color': '207de5',
#     'default': False,
#     'description': 'Requires discussion from core team before further action'},
#    {'id': 307649777,
#     'node_id': 'MDU6TGFiZWwzMDc2NDk3Nzc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info',
#     'name': 'Needs Info',
#     'color': '207de5',
#     'default': False,
#     'description': 'Clarification about behavior needed to assess issue'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 6,
#   'created_at': '2025-03-21T21:26:28Z',
#   'updated_at': '2025-03-22T17:04:24Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'body': '### Feature Type\n\n- [x] Adding new functionality to pandas\n\n- [ ] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nI often find myself using the merge_asof function on time series data. The tolerance and allow_exact_matches fields are very useful in filtering data, but it would be very useful to have more granular control over this tolerance. Being able to supply a minimum tolerance in addition to the currently existing maximum tolerance would be very beneficial in giving the user more control over this function.\n\n### Feature Description\n\nA current example for this function is the following:\n\nWe only asof within 10ms between the quote time and the trade time\n    and we exclude exact matches on time. However *prior* data will\n    propagate forward\n\n    >>> pd.merge_asof(\n    ...     trades,\n    ...     quotes,\n    ...     on="time",\n    ...     by="ticker",\n    ...     tolerance=pd.Timedelta("10ms"),\n    ...     allow_exact_matches=False\n    ... )\n                         time ticker   price  quantity     bid     ask\n    0 2016-05-25 13:30:00.023   MSFT   51.95        75     NaN     NaN\n    1 2016-05-25 13:30:00.038   MSFT   51.95       155   51.97   51.98\n    2 2016-05-25 13:30:00.048   GOOG  720.77       100     NaN     NaN\n    3 2016-05-25 13:30:00.048   GOOG  720.92       100     NaN     NaN\n    4 2016-05-25 13:30:00.048   AAPL   98.00       100     NaN     NaN\n\nI am envisining a version where we could have\n\nWe only asof within 10ms between the quote time and the trade time but more than 2ms between the quote time and the trade time and we exclude exact matches on time. However *prior* data will propagate forward\n\n    >>> pd.merge_asof(\n    ...     trades,\n    ...     quotes,\n    ...     on="time",\n    ...     by="ticker",\n    ...     tolerance=pd.Timedelta("10ms"),\n    ...     mininum_tolerance=pd.Timedelta("2ms"),\n    ...     allow_exact_matches=False\n    ... )\n                         time ticker   price  quantity     bid     ask\n    0 2016-05-25 13:30:00.023   MSFT   51.95        75     NaN     NaN\n    1 2016-05-25 13:30:00.038   MSFT   51.95       155   51.97   51.98\n    2 2016-05-25 13:30:00.048   GOOG  720.77       100     NaN     NaN\n    3 2016-05-25 13:30:00.048   GOOG  720.92       100     NaN     NaN\n    4 2016-05-25 13:30:00.048   AAPL   98.00       100     NaN     NaN\n\n\n### Alternative Solutions\n\nAnother solution to this problem to augment the currently existing tolerance argument to accept a single datetimelike object, or a tuple of datetmelike objects which could act as a lower and upper bound, respectively.\n\n### Additional Context\n\n_No response_',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61164/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61164/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61163',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61163/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61163/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61163/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61163',
#   'id': 2939434124,
#   'node_id': 'PR_kwDOAA0YD86PrIFz',
#   'number': 61163,
#   'title': 'WEB: Remove self (Marco Gorelli) from "active maintainers" list',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 1508144531,
#     'node_id': 'MDU6TGFiZWwxNTA4MTQ0NTMx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Web',
#     'name': 'Web',
#     'color': '23ef97',
#     'default': False,
#     'description': 'pandas website'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2025-03-21T20:24:14Z',
#   'updated_at': '2025-03-24T16:00:44Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61163',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61163',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61163.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61163.patch',
#    'merged_at': None},
#   'body': 'This is a bit overdue, but I haven\'t been active (barring minor PRs) for some time. This isn\'t anything personal against anyone, nor against pandas, I\'m just recognising that my involvement has waned, and that unfortunately I don\'t have capacity for pandas maintenance\r\n\r\nThanks everyone for having involved me, I really appreciate it. A highlight for me was meeting many of you in Basel, and on the technical side a personal highlight was working on PDEP-4 and PDEP-6\r\n\r\nThere are some changes I\'ve made which affect 3.0, and I\'m happy to be pinged and to take responsibility for them, but I can do so even just as contributor, no need for me to be in the "active maintainers" list for that\r\n\r\nAll the best 🤗 ',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61163/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61163/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61162',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61162/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61162/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61162/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61162',
#   'id': 2939350569,
#   'node_id': 'PR_kwDOAA0YD86Pq2I5',
#   'number': 61162,
#   'title': 'ENH: Support boolean masks for `iloc.__getitem__`',
#   'user': {'login': 'arthurlw',
#    'id': 126365160,
#    'node_id': 'U_kgDOB4gt6A',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/126365160?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arthurlw',
#    'html_url': 'https://github.com/arthurlw',
#    'followers_url': 'https://api.github.com/users/arthurlw/followers',
#    'following_url': 'https://api.github.com/users/arthurlw/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/arthurlw/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/arthurlw/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/arthurlw/subscriptions',
#    'organizations_url': 'https://api.github.com/users/arthurlw/orgs',
#    'repos_url': 'https://api.github.com/users/arthurlw/repos',
#    'events_url': 'https://api.github.com/users/arthurlw/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/arthurlw/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-03-21T19:44:44Z',
#   'updated_at': '2025-03-21T22:01:10Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61162',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61162',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61162.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61162.patch',
#    'merged_at': None},
#   'body': '- [x] closes #60994 \r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61162/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61162/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61161',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61161/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61161/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61161/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61161',
#   'id': 2939332712,
#   'node_id': 'I_kwDOAA0YD86vMqho',
#   'number': 61161,
#   'title': 'BUG: fails to plot 2 plots with secondary y axis when index type is PeriodIndex and plot kinds are different',
# ...
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61128/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61128/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61126',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61126/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61126/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61126/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61126',
#   'id': 2921699383,
#   'node_id': 'I_kwDOAA0YD86uJZg3',
#   'number': 61126,
#   'title': 'DOC: Write user guide page on apply/map/transform methods',
#   'user': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
#    'followers_url': 'https://api.github.com/users/datapythonista/followers',
#    'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#    'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#    'repos_url': 'https://api.github.com/users/datapythonista/repos',
#    'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform, Map'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'arthurlw',
#    'id': 126365160,
#    'node_id': 'U_kgDOB4gt6A',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/126365160?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arthurlw',
#    'html_url': 'https://github.com/arthurlw',
#    'followers_url': 'https://api.github.com/users/arthurlw/followers',
#    'following_url': 'https://api.github.com/users/arthurlw/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/arthurlw/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/arthurlw/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/arthurlw/subscriptions',
#    'organizations_url': 'https://api.github.com/users/arthurlw/orgs',
#    'repos_url': 'https://api.github.com/users/arthurlw/repos',
#    'events_url': 'https://api.github.com/users/arthurlw/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/arthurlw/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'assignees': [{'login': 'arthurlw',
#     'id': 126365160,
#     'node_id': 'U_kgDOB4gt6A',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126365160?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/arthurlw',
#     'html_url': 'https://github.com/arthurlw',
#     'followers_url': 'https://api.github.com/users/arthurlw/followers',
#     'following_url': 'https://api.github.com/users/arthurlw/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/arthurlw/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/arthurlw/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/arthurlw/subscriptions',
#     'organizations_url': 'https://api.github.com/users/arthurlw/orgs',
#     'repos_url': 'https://api.github.com/users/arthurlw/repos',
#     'events_url': 'https://api.github.com/users/arthurlw/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/arthurlw/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2025-03-15T04:03:22Z',
#   'updated_at': '2025-03-24T18:33:19Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'body': "There is some information in our documentation regarding how to use user defined functions in pandas. The API pages of the used methods, and these sections:\n\n- https://pandas.pydata.org/docs/user_guide/groupby.html#aggregation-with-user-defined-functions\n- https://pandas.pydata.org/docs/user_guide/gotchas.html#gotchas-udf-mutation\n\nMy understanding is that we've been mostly discouraging the use of functions like apply, or at least the community has with many posts and comments regarding `apply` is slow, which seem fair. With the work going on supporting JIT compilers on these functions (see https://github.com/pandas-dev/pandas/pull/54666 and https://github.com/pandas-dev/pandas/pull/61032) this can hopefully change, and allow in some cases for clearer code while not compromising speed.\n\nI think it may be difficult to communicate all the information related to udf in the existing sections on group by and FAQ pages and in the API docs. A dedicated page in the users guide that guides users on when to use udf, a general idea of the API, the differences between the different methods, the options available... seems a better idea.\n\nAlso, the APIs of the different methods are quite inconsistent, and in some cases cumbersome. I think writing this page will be a good exercise to identify cases when explaining the functionality to the users is complex and not intuitive, and see if we can address them.",
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61126/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61126/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61125',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61125/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61125/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61125/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61125',
#   'id': 2921670139,
#   'node_id': 'I_kwDOAA0YD86uJSX7',
#   'number': 61125,
#   'title': 'ENH: Supporting third-party engines for all `map` and `apply` methods',
#   'user': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
#    'followers_url': 'https://api.github.com/users/datapythonista/followers',
#    'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#    'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#    'repos_url': 'https://api.github.com/users/datapythonista/repos',
#    'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform, Map'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 13,
#   'created_at': '2025-03-15T03:21:13Z',
#   'updated_at': '2025-03-20T15:31:54Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'body': 'In #54666 and #61032 we introduce the `engine` parameter to `DataFrame.apply` which allows users to run the operation with a third-party engine.\n\nThe rest of `apply` and `map` methods can also benefit from this.\n\nIn a first phase we can do:\n\n- `Series.map`\n- `Series.apply`\n- `DataFrame.map`\n\nThen we can continue with the transform and  group by ones.',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61125/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61125/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61124',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61124/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61124/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61124/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61124',
#   'id': 2921561579,
#   'node_id': 'I_kwDOAA0YD86uI33r',
#   'number': 61124,
#   'title': "ENH: fillna enhancement with method='nearest'",
#   'user': {'login': 'mennowitteveen',
#    'id': 6292714,
#    'node_id': 'MDQ6VXNlcjYyOTI3MTQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6292714?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mennowitteveen',
#    'html_url': 'https://github.com/mennowitteveen',
#    'followers_url': 'https://api.github.com/users/mennowitteveen/followers',
#    'following_url': 'https://api.github.com/users/mennowitteveen/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mennowitteveen/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mennowitteveen/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mennowitteveen/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mennowitteveen/orgs',
#    'repos_url': 'https://api.github.com/users/mennowitteveen/repos',
#    'events_url': 'https://api.github.com/users/mennowitteveen/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mennowitteveen/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 2822342,
#     'node_id': 'MDU6TGFiZWwyODIyMzQy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Missing-data',
#     'name': 'Missing-data',
#     'color': 'd7e102',
#     'default': False,
#     'description': 'np.nan, pd.NaT, pd.NA, dropna, isnull, interpolate'},
#    {'id': 307649777,
#     'node_id': 'MDU6TGFiZWwzMDc2NDk3Nzc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info',
#     'name': 'Needs Info',
#     'color': '207de5',
#     'default': False,
#     'description': 'Clarification about behavior needed to assess issue'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2025-03-15T01:03:57Z',
#   'updated_at': '2025-03-19T20:02:29Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'body': "### Feature Type\n\n- [x] Adding new functionality to pandas\n\n- [ ] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nThis should be a simple follow-up to https://github.com/pandas-dev/pandas/issues/9471, enabling support for alignment with method='nearest'.\n\nSince fillna internally uses interpolate, which already supports method='nearest', this might work right away, though it will require extensive testing.\n\n### Feature Description\n\nThe new feature could be implemented by extending the current alignment functionality in Pandas to support `method='nearest'`. This would allow the user to align two Series or DataFrames by their indices, using the nearest available value when exact matches are not found. Here's a basic idea of how it could be implemented in pseudocode:\n\n```python\ndef align_nearest(df1, df2):\n    # Use a nearest neighbor search to align the indices\n    df1_nearest = df1.reindex(df2.index, method='nearest')\n    return df1_nearest\n```\n\nThis functionality could be added as a method to the existing `pandas.DataFrame` and `pandas.Series` objects, integrating smoothly into the current API.\n\n\n### Alternative Solutions\n\n  An alternative solution would be to use the existing `interpolate` function with `method='nearest'`, which can be applied to the DataFrame or Series before performing the alignment. Additionally, third-party libraries like `fuzzywuzzy` or `scipy.spatial` could be used for more complex nearest matching.\n\n```python\nimport pandas as pd\nfrom fuzzywuzzy import process\n\n# Example using fuzzywuzzy to find nearest match\ndf1 = pd.DataFrame([...])\ndf2 = pd.DataFrame([...])\ndf1['nearest'] = df1['index_column'].apply(lambda x: process.extractOne(x, df2['index_column'])[0])\n```\n\nHowever, native support within Pandas would likely be more efficient and user-friendly.\n\n\n### Additional Context\n\n ",
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61124/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61124/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %% [markdown]
# ## Scraping JSON using urllib lib
#
# Please find the last 30 GitHub issues for pandas on GitHub.

# %%
from urllib.request import urlopen
import json
url='https://api.github.com/repos/pandas-dev/pandas/issues'
htmlfile = urlopen(url)
htmltext=htmlfile.read() #htmltext is a json string object
data = json.loads(htmltext) #json.loads() method convert a json string to a list of Python dictionaries. 
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61173',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61173/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61173/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61173/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61173',
#   'id': 2942576054,
#   'node_id': 'PR_kwDOAA0YD86P1abm',
#   'number': 61173,
#   'title': 'BUG: Handle line and bar on the same plot',
#   'user': {'login': 'MartinBraquet',
#    'id': 25173236,
#    'node_id': 'MDQ6VXNlcjI1MTczMjM2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25173236?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MartinBraquet',
#    'html_url': 'https://github.com/MartinBraquet',
#    'followers_url': 'https://api.github.com/users/MartinBraquet/followers',
#    'following_url': 'https://api.github.com/users/MartinBraquet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MartinBraquet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MartinBraquet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MartinBraquet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MartinBraquet/orgs',
#    'repos_url': 'https://api.github.com/users/MartinBraquet/repos',
#    'events_url': 'https://api.github.com/users/MartinBraquet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MartinBraquet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-03-24T09:22:19Z',
#   'updated_at': '2025-03-24T10:51:17Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61173',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61173',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61173.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61173.patch',
#    'merged_at': None},
#   'body': "- [x] closes #61161\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nPlease provide feedback on the overall approach. Once confirmed, I'll expand and cover with tests.\r\n",
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61173/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61173/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61172',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61172/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61172/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61172/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61172',
#   'id': 2941851698,
#   'node_id': 'I_kwDOAA0YD86vWRgy',
#   'number': 61172,
#   'title': 'BUG: pd.read_csv() on empty files should give an empty dataframe pd.DataFrame()',
#   'user': {'login': 'xuancong84',
#    'id': 10172392,
#    'node_id': 'MDQ6VXNlcjEwMTcyMzky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10172392?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xuancong84',
#    'html_url': 'https://github.com/xuancong84',
#    'followers_url': 'https://api.github.com/users/xuancong84/followers',
#    'following_url': 'https://api.github.com/users/xuancong84/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/xuancong84/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/xuancong84/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/xuancong84/subscriptions',
#    'organizations_url': 'https://api.github.com/users/xuancong84/orgs',
#    'repos_url': 'https://api.github.com/users/xuancong84/repos',
#    'events_url': 'https://api.github.com/users/xuancong84/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/xuancong84/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_csv, to_csv'},
#    {'id': 2365504893,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0ODkz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Closing%20Candidate',
#     'name': 'Closing Candidate',
#     'color': 'be21f2',
#     'default': False,
#     'description': 'May be closeable, needs more eyeballs'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'MartinBraquet',
#    'id': 25173236,
#    'node_id': 'MDQ6VXNlcjI1MTczMjM2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25173236?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MartinBraquet',
#    'html_url': 'https://github.com/MartinBraquet',
#    'followers_url': 'https://api.github.com/users/MartinBraquet/followers',
#    'following_url': 'https://api.github.com/users/MartinBraquet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MartinBraquet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MartinBraquet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MartinBraquet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MartinBraquet/orgs',
#    'repos_url': 'https://api.github.com/users/MartinBraquet/repos',
#    'events_url': 'https://api.github.com/users/MartinBraquet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MartinBraquet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'assignees': [{'login': 'MartinBraquet',
#     'id': 25173236,
#     'node_id': 'MDQ6VXNlcjI1MTczMjM2',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/25173236?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/MartinBraquet',
#     'html_url': 'https://github.com/MartinBraquet',
#     'followers_url': 'https://api.github.com/users/MartinBraquet/followers',
#     'following_url': 'https://api.github.com/users/MartinBraquet/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/MartinBraquet/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/MartinBraquet/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/MartinBraquet/subscriptions',
#     'organizations_url': 'https://api.github.com/users/MartinBraquet/orgs',
#     'repos_url': 'https://api.github.com/users/MartinBraquet/repos',
#     'events_url': 'https://api.github.com/users/MartinBraquet/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/MartinBraquet/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-03-24T03:07:45Z',
#   'updated_at': '2025-03-24T20:51:16Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [x] I have checked that this issue has not already been reported.\n\n- [x] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [x] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nUsing `pd.read_csv()` to open an empty CSV file (0-bytes file or single-byte file (EOL character) by VIM) will give the following error:\n\nTraceback (most recent call last):\n  File "<stdin>", line 1, in <module>\n  File "/home/xuancong/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py", line 1026, in read_csv\n    return _read(filepath_or_buffer, kwds)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/xuancong/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py", line 620, in _read\n    parser = TextFileReader(filepath_or_buffer, **kwds)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/xuancong/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py", line 1620, in __init__\n    self._engine = self._make_engine(f, self.engine)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/xuancong/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py", line 1898, in _make_engine\n    return mapping[engine](f, **self.options)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/xuancong/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py", line 93, in __init__\n    self._reader = parsers.TextReader(src, **kwds)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "parsers.pyx", line 581, in pandas._libs.parsers.TextReader.__cinit__\npandas.errors.EmptyDataError: No columns to parse from file\n```\n\n### Issue Description\n\nThe reason of the crash is that there is no columns to parse. However, Pandas does allow dataframes with no columns and no rows, i.e., `pd.DataFrame()` gives an empty DataFrame with no rows and no columns.\n\nThe logic reasoning is that if opening an empty CSV will cause crash, then **opening what kind of CSV file will give rise to an empty DataFrame**? When designing APIs, one fundamental principle is to try to keep a 1-to-1 mapping between input and output (so as to reduce information loss); thus, in this case, it is the mapping between CSV file and dataframe. I do agree that if the CSV does not exist or cannot be read (due to permission), then the call should crash. But if the CSV file is empty, `pd.read_csv()` should give an empty dataframe because empty dataframe does exist. Otherwise, what text should I put into a CSV file so that `pd.read_csv()` will give an empty DataFrame, i.e., `pd.DataFrame()`? Thanks!\n\n### Expected Behavior\n\nOpening an empty CSV file should give an empty DataFrame (i.e., pd.DataFrame()):\n```\nEmpty DataFrame\nColumns: []\nIndex: []\n```\n\n### Installed Versions\n\n<details>\n\nINSTALLED VERSIONS\n------------------\ncommit                : 0691c5cf90477d3503834d983f69350f250a6ff7\npython                : 3.11.5\npython-bits           : 64\nOS                    : Linux\nOS-release            : 6.8.0-52-generic\nVersion               : #53~22.04.1-Ubuntu SMP PREEMPT_DYNAMIC Wed Jan 15 19:18:46 UTC 2\nmachine               : x86_64\nprocessor             : x86_64\nbyteorder             : little\nLC_ALL                : en_US.UTF-8\nLANG                  : en_US.UTF-8\nLOCALE                : en_US.UTF-8\n\npandas                : 2.2.3\nnumpy                 : 1.26.4\npytz                  : 2023.3.post1\ndateutil              : 2.8.2\npip                   : 25.0.1\nCython                : None\nsphinx                : 5.0.2\nIPython               : 8.15.0\nadbc-driver-postgresql: None\nadbc-driver-sqlite    : None\nbs4                   : 4.12.2\nblosc                 : None\nbot ...
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61172/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61172/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61171',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61171/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61171/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61171/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61171',
#   'id': 2941462140,
#   'node_id': 'PR_kwDOAA0YD86Pxsxt',
#   'number': 61171,
#   'title': 'DataFrame.dtypes.to_json OverflowError: Maximum recursion level reached',
#   'user': {'login': 'Aliebc',
#    'id': 89406058,
#    'node_id': 'MDQ6VXNlcjg5NDA2MDU4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89406058?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Aliebc',
#    'html_url': 'https://github.com/Aliebc',
#    'followers_url': 'https://api.github.com/users/Aliebc/followers',
#    'following_url': 'https://api.github.com/users/Aliebc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Aliebc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Aliebc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Aliebc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Aliebc/orgs',
#    'repos_url': 'https://api.github.com/users/Aliebc/repos',
#    'events_url': 'https://api.github.com/users/Aliebc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Aliebc/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-03-23T20:16:22Z',
#   'updated_at': '2025-03-24T20:06:28Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61171',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61171',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61171.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61171.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #61170  (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61171/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61171/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61170',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61170/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61170/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61170/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61170',
#   'id': 2941455212,
#   'node_id': 'I_kwDOAA0YD86vUwts',
#   'number': 61170,
#   'title': 'BUG: DataFrame.dtypes.to_json OverflowError: Maximum recursion level reached',
#   'user': {'login': 'Aliebc',
#    'id': 89406058,
#    'node_id': 'MDQ6VXNlcjg5NDA2MDU4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89406058?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Aliebc',
#    'html_url': 'https://github.com/Aliebc',
#    'followers_url': 'https://api.github.com/users/Aliebc/followers',
#    'following_url': 'https://api.github.com/users/Aliebc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Aliebc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Aliebc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Aliebc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Aliebc/orgs',
#    'repos_url': 'https://api.github.com/users/Aliebc/repos',
#    'events_url': 'https://api.github.com/users/Aliebc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Aliebc/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 49379259,
#     'node_id': 'MDU6TGFiZWw0OTM3OTI1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20JSON',
#     'name': 'IO JSON',
#     'color': '207de5',
#     'default': False,
#     'description': 'read_json, to_json, json_normalize'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'GalkaKG',
#    'id': 103485495,
#    'node_id': 'U_kgDOBisQNw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103485495?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GalkaKG',
#    'html_url': 'https://github.com/GalkaKG',
#    'followers_url': 'https://api.github.com/users/GalkaKG/followers',
#    'following_url': 'https://api.github.com/users/GalkaKG/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/GalkaKG/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/GalkaKG/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/GalkaKG/subscriptions',
#    'organizations_url': 'https://api.github.com/users/GalkaKG/orgs',
#    'repos_url': 'https://api.github.com/users/GalkaKG/repos',
#    'events_url': 'https://api.github.com/users/GalkaKG/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/GalkaKG/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'assignees': [{'login': 'GalkaKG',
#     'id': 103485495,
#     'node_id': 'U_kgDOBisQNw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/103485495?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/GalkaKG',
#     'html_url': 'https://github.com/GalkaKG',
#     'followers_url': 'https://api.github.com/users/GalkaKG/followers',
#     'following_url': 'https://api.github.com/users/GalkaKG/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/GalkaKG/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/GalkaKG/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/GalkaKG/subscriptions',
#     'organizations_url': 'https://api.github.com/users/GalkaKG/orgs',
#     'repos_url': 'https://api.github.com/users/GalkaKG/repos',
#     'events_url': 'https://api.github.com/users/GalkaKG/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/GalkaKG/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2025-03-23T20:08:19Z',
#   'updated_at': '2025-03-24T13:11:45Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [x] I have checked that this issue has not already been reported.\n\n- [x] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [x] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\nfrom io import StringIO\n\ndf = pd.DataFrame({\'A\': [1, 2, 3], \'B\': [4, 5, 6]})\n\ndts = df.dtypes\nprint(dts)\n\n# dts to csv\n# Expected: A,int64\\nB,int64\\n No error\ntest_csv = StringIO()\ndts.to_csv(test_csv)\nprint(test_csv.getvalue())\n\n# dts to json\n# Expected: {"A": "int64", "B": "int64"} No error\nprint(dts.to_json())\n# OverflowError: Maximum recursion level reached\n```\n\n### Issue Description\n\nWhen calling `to_csv()` on a `pd.Series` of `dtypes`, it works without error and outputs as expected. However, calling `to_json()` on the same `Series` raises an `OverflowError: Maximum recursion level reached`.\n\n### Expected Behavior\n\nExpected: {"A": "int64", "B": "int64"} without error\n\n### Installed Versions\n\nINSTALLED VERSIONS\n------------------\ncommit                : d9cdd2ee5a58015ef6f4d15c7226110c9aab8140\npython                : 3.11.11.final.0\npython-bits           : 64\nOS                    : Darwin\nOS-release            : 24.3.0\nVersion               : Darwin Kernel Version 24.3.0: Thu Jan  2 20:24:23 PST 2025; root:xnu-11215.81.4~3/RELEASE_ARM64_T6020\nmachine               : arm64\nprocessor             : arm\nbyteorder             : little\nLC_ALL                : None\nLANG                  : zh_CN.UTF-8\nLOCALE                : zh_CN.UTF-8\n\npandas                : 2.2.2\nnumpy                 : 1.26.4\npytz                  : 2022.6\ndateutil              : 2.8.2\nsetuptools            : 75.6.0\npip                   : 24.3.1\nCython                : None\npytest                : 8.2.2\nhypothesis            : None\nsphinx                : None\nblosc                 : None\nfeather               : None\nxlsxwriter            : None\nlxml.etree            : 4.9.3\nhtml5lib              : 1.1\npymysql               : None\npsycopg2              : None\njinja2                : 3.1.2\nIPython               : 8.11.0\npandas_datareader     : None\nadbc-driver-postgresql: None\nadbc-driver-sqlite    : None\nbs4                   : 4.12.2\nbottleneck            : None\ndataframe-api-compat  : None\nfastparquet           : None\nfsspec                : 2023.12.2\ngcsfs                 : None\nmatplotlib            : 3.8.3\nnumba                 : 0.58.1\nnumexpr               : None\nodfpy                 : None\nopenpyxl              : 3.1.2\npandas_gbq            : None\npyarrow               : 14.0.1\npyreadstat            : None\npython-calamine       : None\npyxlsb                : None\ns3fs                  : None\nscipy                 : 1.12.0\nsqlalchemy            : None\ntables                : None\ntabulate              : None\nxarray                : None\nxlrd                  : 2.0.1\nzstandard             : None\ntzdata                : 2024.1\nqtpy                  : None\npyqt5                 : None\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61170/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61170/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61168',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61168/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61168/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61168/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61168',
#   'id': 2941184864,
#   'node_id': 'PR_kwDOAA0YD86Pw0Ry',
#   'number': 61168,
#   'title': 'ENH: Accept no fields for groupby by',
#   'user': {'login': 'udit710',
#    'id': 103230240,
#    'node_id': 'U_kgDOBicrIA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103230240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/udit710',
#    'html_url': 'https://github.com/udit710',
#    'followers_url': 'https://api.github.com/users/udit710/followers',
#    'following_url': 'https://api.github.com/users/udit710/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/udit710/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/udit710/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/udit710/subscriptions',
#    'organizations_url': 'https://api.github.com/users/udit710/orgs',
#    'repos_url': 'https://api.github.com/users/udit710/repos',
#    'events_url': 'https://api.github.com/users/udit710/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/udit710/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2025-03-23T13:21:20Z',
#   'updated_at': '2025-03-24T05:50:04Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61168',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61168',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61168.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61168.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #61160 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61168/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61168/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61166',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61166/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61166/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61166/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61166',
#   'id': 2940295236,
#   'node_id': 'I_kwDOAA0YD86vQVhE',
#   'number': 61166,
#   'title': 'ENH: Enable nsmallest/nlargest on object dtype',
#   'user': {'login': 'Gri72',
#    'id': 61454390,
#    'node_id': 'MDQ6VXNlcjYxNDU0Mzkw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61454390?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Gri72',
#    'html_url': 'https://github.com/Gri72',
#    'followers_url': 'https://api.github.com/users/Gri72/followers',
#    'following_url': 'https://api.github.com/users/Gri72/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Gri72/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Gri72/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Gri72/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Gri72/orgs',
#    'repos_url': 'https://api.github.com/users/Gri72/repos',
#    'events_url': 'https://api.github.com/users/Gri72/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Gri72/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 5432590063,
#     'node_id': 'LA_kwDOAA0YD88AAAABQ86-7w',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Filters',
#     'name': 'Filters',
#     'color': '8EFC7E',
#     'default': False,
#     'description': 'e.g. head, tail, nth'},
#    {'id': 6323552771,
#     'node_id': 'LA_kwDOAA0YD88AAAABeOnCAw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Sorting',
#     'name': 'Sorting',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'e.g. sort_index, sort_values'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'RutujaGhodake',
#    'id': 135499591,
#    'node_id': 'U_kgDOCBOPRw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/135499591?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RutujaGhodake',
#    'html_url': 'https://github.com/RutujaGhodake',
#    'followers_url': 'https://api.github.com/users/RutujaGhodake/followers',
#    'following_url': 'https://api.github.com/users/RutujaGhodake/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/RutujaGhodake/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/RutujaGhodake/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/RutujaGhodake/subscriptions',
#    'organizations_url': 'https://api.github.com/users/RutujaGhodake/orgs',
#    'repos_url': 'https://api.github.com/users/RutujaGhodake/repos',
#    'events_url': 'https://api.github.com/users/RutujaGhodake/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/RutujaGhodake/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'assignees': [{'login': 'RutujaGhodake',
#     'id': 135499591,
#     'node_id': 'U_kgDOCBOPRw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/135499591?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/RutujaGhodake',
#     'html_url': 'https://github.com/RutujaGhodake',
#     'followers_url': 'https://api.github.com/users/RutujaGhodake/followers',
#     'following_url': 'https://api.github.com/users/RutujaGhodake/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/RutujaGhodake/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/RutujaGhodake/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/RutujaGhodake/subscriptions',
#     'organizations_url': 'https://api.github.com/users/RutujaGhodake/orgs',
#     'repos_url': 'https://api.github.com/users/RutujaGhodake/repos',
#     'events_url': 'https://api.github.com/users/RutujaGhodake/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/RutujaGhodake/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2025-03-22T10:36:03Z',
#   'updated_at': '2025-03-24T06:18:00Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'body': 'Is it possible to implement method DataFrame.nsorted that equivalent to `df.sort_values(by=["col1", "col2"], ascending=[True, False]).head(k)`, but with time complexity O(n log k)? I know about `nlargest` and `nsmallest` methods but unfortunately they work only with numeric columns.\n\nExample:\n```python\ndf.nsorted(k=6, by=["col1", "col2"], ascending=[True, False])\n```',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61166/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61166/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61164',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61164/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61164/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61164/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61164',
#   'id': 2939534423,
#   'node_id': 'I_kwDOAA0YD86vNbxX',
#   'number': 61164,
#   'title': 'ENH: merge_asof threshold minimum',
#   'user': {'login': 'Lituchy',
#    'id': 41648348,
#    'node_id': 'MDQ6VXNlcjQxNjQ4MzQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41648348?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Lituchy',
#    'html_url': 'https://github.com/Lituchy',
#    'followers_url': 'https://api.github.com/users/Lituchy/followers',
#    'following_url': 'https://api.github.com/users/Lituchy/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Lituchy/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Lituchy/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Lituchy/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Lituchy/orgs',
#    'repos_url': 'https://api.github.com/users/Lituchy/repos',
#    'events_url': 'https://api.github.com/users/Lituchy/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Lituchy/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'},
#    {'id': 219960758,
#     'node_id': 'MDU6TGFiZWwyMTk5NjA3NTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Discussion',
#     'name': 'Needs Discussion',
#     'color': '207de5',
#     'default': False,
#     'description': 'Requires discussion from core team before further action'},
#    {'id': 307649777,
#     'node_id': 'MDU6TGFiZWwzMDc2NDk3Nzc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info',
#     'name': 'Needs Info',
#     'color': '207de5',
#     'default': False,
#     'description': 'Clarification about behavior needed to assess issue'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 6,
#   'created_at': '2025-03-21T21:26:28Z',
#   'updated_at': '2025-03-22T17:04:24Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'body': '### Feature Type\n\n- [x] Adding new functionality to pandas\n\n- [ ] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nI often find myself using the merge_asof function on time series data. The tolerance and allow_exact_matches fields are very useful in filtering data, but it would be very useful to have more granular control over this tolerance. Being able to supply a minimum tolerance in addition to the currently existing maximum tolerance would be very beneficial in giving the user more control over this function.\n\n### Feature Description\n\nA current example for this function is the following:\n\nWe only asof within 10ms between the quote time and the trade time\n    and we exclude exact matches on time. However *prior* data will\n    propagate forward\n\n    >>> pd.merge_asof(\n    ...     trades,\n    ...     quotes,\n    ...     on="time",\n    ...     by="ticker",\n    ...     tolerance=pd.Timedelta("10ms"),\n    ...     allow_exact_matches=False\n    ... )\n                         time ticker   price  quantity     bid     ask\n    0 2016-05-25 13:30:00.023   MSFT   51.95        75     NaN     NaN\n    1 2016-05-25 13:30:00.038   MSFT   51.95       155   51.97   51.98\n    2 2016-05-25 13:30:00.048   GOOG  720.77       100     NaN     NaN\n    3 2016-05-25 13:30:00.048   GOOG  720.92       100     NaN     NaN\n    4 2016-05-25 13:30:00.048   AAPL   98.00       100     NaN     NaN\n\nI am envisining a version where we could have\n\nWe only asof within 10ms between the quote time and the trade time but more than 2ms between the quote time and the trade time and we exclude exact matches on time. However *prior* data will propagate forward\n\n    >>> pd.merge_asof(\n    ...     trades,\n    ...     quotes,\n    ...     on="time",\n    ...     by="ticker",\n    ...     tolerance=pd.Timedelta("10ms"),\n    ...     mininum_tolerance=pd.Timedelta("2ms"),\n    ...     allow_exact_matches=False\n    ... )\n                         time ticker   price  quantity     bid     ask\n    0 2016-05-25 13:30:00.023   MSFT   51.95        75     NaN     NaN\n    1 2016-05-25 13:30:00.038   MSFT   51.95       155   51.97   51.98\n    2 2016-05-25 13:30:00.048   GOOG  720.77       100     NaN     NaN\n    3 2016-05-25 13:30:00.048   GOOG  720.92       100     NaN     NaN\n    4 2016-05-25 13:30:00.048   AAPL   98.00       100     NaN     NaN\n\n\n### Alternative Solutions\n\nAnother solution to this problem to augment the currently existing tolerance argument to accept a single datetimelike object, or a tuple of datetmelike objects which could act as a lower and upper bound, respectively.\n\n### Additional Context\n\n_No response_',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61164/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61164/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61163',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61163/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61163/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61163/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61163',
#   'id': 2939434124,
#   'node_id': 'PR_kwDOAA0YD86PrIFz',
#   'number': 61163,
#   'title': 'WEB: Remove self (Marco Gorelli) from "active maintainers" list',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 1508144531,
#     'node_id': 'MDU6TGFiZWwxNTA4MTQ0NTMx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Web',
#     'name': 'Web',
#     'color': '23ef97',
#     'default': False,
#     'description': 'pandas website'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2025-03-21T20:24:14Z',
#   'updated_at': '2025-03-24T16:00:44Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61163',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61163',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61163.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61163.patch',
#    'merged_at': None},
#   'body': 'This is a bit overdue, but I haven\'t been active (barring minor PRs) for some time. This isn\'t anything personal against anyone, nor against pandas, I\'m just recognising that my involvement has waned, and that unfortunately I don\'t have capacity for pandas maintenance\r\n\r\nThanks everyone for having involved me, I really appreciate it. A highlight for me was meeting many of you in Basel, and on the technical side a personal highlight was working on PDEP-4 and PDEP-6\r\n\r\nThere are some changes I\'ve made which affect 3.0, and I\'m happy to be pinged and to take responsibility for them, but I can do so even just as contributor, no need for me to be in the "active maintainers" list for that\r\n\r\nAll the best 🤗 ',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61163/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61163/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61162',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61162/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61162/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61162/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61162',
#   'id': 2939350569,
#   'node_id': 'PR_kwDOAA0YD86Pq2I5',
#   'number': 61162,
#   'title': 'ENH: Support boolean masks for `iloc.__getitem__`',
#   'user': {'login': 'arthurlw',
#    'id': 126365160,
#    'node_id': 'U_kgDOB4gt6A',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/126365160?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arthurlw',
#    'html_url': 'https://github.com/arthurlw',
#    'followers_url': 'https://api.github.com/users/arthurlw/followers',
#    'following_url': 'https://api.github.com/users/arthurlw/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/arthurlw/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/arthurlw/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/arthurlw/subscriptions',
#    'organizations_url': 'https://api.github.com/users/arthurlw/orgs',
#    'repos_url': 'https://api.github.com/users/arthurlw/repos',
#    'events_url': 'https://api.github.com/users/arthurlw/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/arthurlw/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-03-21T19:44:44Z',
#   'updated_at': '2025-03-21T22:01:10Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61162',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61162',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61162.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61162.patch',
#    'merged_at': None},
#   'body': '- [x] closes #60994 \r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61162/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61162/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61161',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61161/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61161/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61161/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61161',
#   'id': 2939332712,
#   'node_id': 'I_kwDOAA0YD86vMqho',
#   'number': 61161,
#   'title': 'BUG: fails to plot 2 plots with secondary y axis when index type is PeriodIndex and plot kinds are different',
# ...
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61128/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61128/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61126',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61126/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61126/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61126/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61126',
#   'id': 2921699383,
#   'node_id': 'I_kwDOAA0YD86uJZg3',
#   'number': 61126,
#   'title': 'DOC: Write user guide page on apply/map/transform methods',
#   'user': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
#    'followers_url': 'https://api.github.com/users/datapythonista/followers',
#    'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#    'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#    'repos_url': 'https://api.github.com/users/datapythonista/repos',
#    'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform, Map'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'arthurlw',
#    'id': 126365160,
#    'node_id': 'U_kgDOB4gt6A',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/126365160?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arthurlw',
#    'html_url': 'https://github.com/arthurlw',
#    'followers_url': 'https://api.github.com/users/arthurlw/followers',
#    'following_url': 'https://api.github.com/users/arthurlw/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/arthurlw/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/arthurlw/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/arthurlw/subscriptions',
#    'organizations_url': 'https://api.github.com/users/arthurlw/orgs',
#    'repos_url': 'https://api.github.com/users/arthurlw/repos',
#    'events_url': 'https://api.github.com/users/arthurlw/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/arthurlw/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'assignees': [{'login': 'arthurlw',
#     'id': 126365160,
#     'node_id': 'U_kgDOB4gt6A',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126365160?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/arthurlw',
#     'html_url': 'https://github.com/arthurlw',
#     'followers_url': 'https://api.github.com/users/arthurlw/followers',
#     'following_url': 'https://api.github.com/users/arthurlw/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/arthurlw/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/arthurlw/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/arthurlw/subscriptions',
#     'organizations_url': 'https://api.github.com/users/arthurlw/orgs',
#     'repos_url': 'https://api.github.com/users/arthurlw/repos',
#     'events_url': 'https://api.github.com/users/arthurlw/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/arthurlw/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2025-03-15T04:03:22Z',
#   'updated_at': '2025-03-24T18:33:19Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'body': "There is some information in our documentation regarding how to use user defined functions in pandas. The API pages of the used methods, and these sections:\n\n- https://pandas.pydata.org/docs/user_guide/groupby.html#aggregation-with-user-defined-functions\n- https://pandas.pydata.org/docs/user_guide/gotchas.html#gotchas-udf-mutation\n\nMy understanding is that we've been mostly discouraging the use of functions like apply, or at least the community has with many posts and comments regarding `apply` is slow, which seem fair. With the work going on supporting JIT compilers on these functions (see https://github.com/pandas-dev/pandas/pull/54666 and https://github.com/pandas-dev/pandas/pull/61032) this can hopefully change, and allow in some cases for clearer code while not compromising speed.\n\nI think it may be difficult to communicate all the information related to udf in the existing sections on group by and FAQ pages and in the API docs. A dedicated page in the users guide that guides users on when to use udf, a general idea of the API, the differences between the different methods, the options available... seems a better idea.\n\nAlso, the APIs of the different methods are quite inconsistent, and in some cases cumbersome. I think writing this page will be a good exercise to identify cases when explaining the functionality to the users is complex and not intuitive, and see if we can address them.",
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61126/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61126/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61125',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61125/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61125/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61125/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61125',
#   'id': 2921670139,
#   'node_id': 'I_kwDOAA0YD86uJSX7',
#   'number': 61125,
#   'title': 'ENH: Supporting third-party engines for all `map` and `apply` methods',
#   'user': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
#    'followers_url': 'https://api.github.com/users/datapythonista/followers',
#    'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#    'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#    'repos_url': 'https://api.github.com/users/datapythonista/repos',
#    'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform, Map'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 13,
#   'created_at': '2025-03-15T03:21:13Z',
#   'updated_at': '2025-03-20T15:31:54Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'body': 'In #54666 and #61032 we introduce the `engine` parameter to `DataFrame.apply` which allows users to run the operation with a third-party engine.\n\nThe rest of `apply` and `map` methods can also benefit from this.\n\nIn a first phase we can do:\n\n- `Series.map`\n- `Series.apply`\n- `DataFrame.map`\n\nThen we can continue with the transform and  group by ones.',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61125/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61125/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61124',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61124/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61124/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61124/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61124',
#   'id': 2921561579,
#   'node_id': 'I_kwDOAA0YD86uI33r',
#   'number': 61124,
#   'title': "ENH: fillna enhancement with method='nearest'",
#   'user': {'login': 'mennowitteveen',
#    'id': 6292714,
#    'node_id': 'MDQ6VXNlcjYyOTI3MTQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6292714?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mennowitteveen',
#    'html_url': 'https://github.com/mennowitteveen',
#    'followers_url': 'https://api.github.com/users/mennowitteveen/followers',
#    'following_url': 'https://api.github.com/users/mennowitteveen/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mennowitteveen/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mennowitteveen/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mennowitteveen/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mennowitteveen/orgs',
#    'repos_url': 'https://api.github.com/users/mennowitteveen/repos',
#    'events_url': 'https://api.github.com/users/mennowitteveen/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mennowitteveen/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 2822342,
#     'node_id': 'MDU6TGFiZWwyODIyMzQy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Missing-data',
#     'name': 'Missing-data',
#     'color': 'd7e102',
#     'default': False,
#     'description': 'np.nan, pd.NaT, pd.NA, dropna, isnull, interpolate'},
#    {'id': 307649777,
#     'node_id': 'MDU6TGFiZWwzMDc2NDk3Nzc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info',
#     'name': 'Needs Info',
#     'color': '207de5',
#     'default': False,
#     'description': 'Clarification about behavior needed to assess issue'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2025-03-15T01:03:57Z',
#   'updated_at': '2025-03-19T20:02:29Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'active_lock_reason': None,
#   'body': "### Feature Type\n\n- [x] Adding new functionality to pandas\n\n- [ ] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nThis should be a simple follow-up to https://github.com/pandas-dev/pandas/issues/9471, enabling support for alignment with method='nearest'.\n\nSince fillna internally uses interpolate, which already supports method='nearest', this might work right away, though it will require extensive testing.\n\n### Feature Description\n\nThe new feature could be implemented by extending the current alignment functionality in Pandas to support `method='nearest'`. This would allow the user to align two Series or DataFrames by their indices, using the nearest available value when exact matches are not found. Here's a basic idea of how it could be implemented in pseudocode:\n\n```python\ndef align_nearest(df1, df2):\n    # Use a nearest neighbor search to align the indices\n    df1_nearest = df1.reindex(df2.index, method='nearest')\n    return df1_nearest\n```\n\nThis functionality could be added as a method to the existing `pandas.DataFrame` and `pandas.Series` objects, integrating smoothly into the current API.\n\n\n### Alternative Solutions\n\n  An alternative solution would be to use the existing `interpolate` function with `method='nearest'`, which can be applied to the DataFrame or Series before performing the alignment. Additionally, third-party libraries like `fuzzywuzzy` or `scipy.spatial` could be used for more complex nearest matching.\n\n```python\nimport pandas as pd\nfrom fuzzywuzzy import process\n\n# Example using fuzzywuzzy to find nearest match\ndf1 = pd.DataFrame([...])\ndf2 = pd.DataFrame([...])\ndf1['nearest'] = df1['index_column'].apply(lambda x: process.extractOne(x, df2['index_column'])[0])\n```\n\nHowever, native support within Pandas would likely be more efficient and user-friendly.\n\n\n### Additional Context\n\n ",
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61124/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61124/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %% [markdown]
# **<font color='red'>Exercise</font>**
#
# Can you name a few common keywords and convert data to a DataFrame that contains the value of those keywords? Howe many rows does it have?

# %%
issues=pd.DataFrame(data,columns=['number','title','labels','state', 'created_at'])
issues
# Out:
#     number                                              title  \
# 0    61173          BUG: Handle line and bar on the same plot
# 1    61172  BUG: pd.read_csv() on empty files should give ...
# 2    61171  DataFrame.dtypes.to_json OverflowError: Maximu...
# 3    61170  BUG: DataFrame.dtypes.to_json OverflowError: M...
# 4    61168               ENH: Accept no fields for groupby by
# 5    61166     ENH: Enable nsmallest/nlargest on object dtype
# 6    61164                  ENH: merge_asof threshold minimum
# 7    61163  WEB: Remove self (Marco Gorelli) from "active ...
# 8    61162  ENH: Support boolean masks for `iloc.__getitem__`
# 9    61161  BUG: fails to plot 2 plots with secondary y ax...
# 10   61160               ENH: Accept no fields for groupby by
# 11   61157                                           Csv func
# 12   61156  BUILD: Cython.Compiler.Errors: 'free_threading...
# 13   61155  BUG: Impossible creation of array with dtype=s...
# 14   61154     BUG: Clip corr edge cases between -1.0 and 1.0
# 15   61153  BUG: import pandas 2.2.3 on WSL 2.4.12.0 raise...
# 16   61152  ENH: Adds `dict` & `**dict` support for `pd.se...
# 17   61151        ENH: Added dict support for `pd.set_option`
# 18   61149  BUG: Added deprecation warning to Timestamp co...
# 19   61148  String dtype: more informative repr (keeping b...
# 20   61145  BUG: Inconsistent index type when using read_c...
# 21   61144  BUG(?): rolling sum with pyarrow types results...
# 22   61143           Preserve column names in empty Dataframe
# 23   61142  BUG: Collision between equivalent frequencies ...
# 24   61140  BUG: `DataFrame.from_records()` ignores `colum...
# 25   61138  API (string dtype): implement hierarchy (NA > ...
# 26   61128                         Improve the apply/map APIs
# 27   61126  DOC: Write user guide page on apply/map/transf...
# 28   61125  ENH: Supporting third-party engines for all `m...
# 29   61124      ENH: fillna enhancement with method='nearest'
#
#                                                labels state  \
# 0                                                  []  open
# 1   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 2                                                  []  open
# 3   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 4                                                  []  open
# 5   [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 6   [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 7   [{'id': 1508144531, 'node_id': 'MDU6TGFiZWwxNT...  open
# 8                                                  []  open
# 9   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 10  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 11                                                 []  open
# 12  [{'id': 129350, 'node_id': 'MDU6TGFiZWwxMjkzNT...  open
# 13  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 14  [{'id': 5331296438, 'node_id': 'LA_kwDOAA0YD88...  open
# 15  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 16                                                 []  open
# 17  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 18                                                 []  open
# 19  [{'id': 13101118, 'node_id': 'MDU6TGFiZWwxMzEw...  open
# 20  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 21  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 22  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 23  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 24  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 25  [{'id': 47223669, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 26  [{'id': 697792067, 'node_id': 'MDU6TGFiZWw2OTc...  open
# 27  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 28  [{'id': 697792067, 'node_id': 'MDU6TGFiZWw2OTc...  open
# 29  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
#
#               created_at
# 0   2025-03-24T09:22:19Z
# 1   2025-03-24T03:07:45Z
# 2   2025-03-23T20:16:22Z
# 3   2025-03-23T20:08:19Z
# 4   2025-03-23T13:21:20Z
# 5   2025-03-22T10:36:03Z
# 6   2025-03-21T21:26:28Z
# 7   2025-03-21T20:24:14Z
# 8   2025-03-21T19:44:44Z
# 9   2025-03-21T19:34:07Z
# 10  2025-03-21T18:19:54Z
# 11  2025-03-20T20:41:52Z
# 12  2025-03-20T17:59:23Z
# 13  2025-03-20T14:25:51Z
# 14  2025-03-20T13:15:41Z
# 15  2025-03-20T10:12:53Z
# 16  2025-03-20T07:07:50Z
# 17  2025-03-20T05:38:08Z
# 18  2025-03-20T01:42:57Z
# 19  2025-03-19T18:35:07Z
# 20  2025-03-19T08:56:21Z
# 21  2025-03-18T15:28:39Z
# 22  2025-03-18T15:25:23Z
# 23  2025-03-18T13:54:49Z
# 24  2025-03-17T18:13:09Z
# 25  2025-03-17T10:08:28Z
# 26  2025-03-15T05:13:02Z
# 27  2025-03-15T04:03:22Z
# 28  2025-03-15T03:21:13Z
# 29  2025-03-15T01:03:57Z

# %% [markdown]
# ## Another Example

# %%
response = requests.get("https://jsonplaceholder.typicode.com/todos")
todos = json.loads(response.text)

# %%
todos[:10]

# %%
# Map of userId to number of complete TODOs for that user
todos_by_user = {}

# Increment complete TODOs count for each user.
for todo in todos:
    if todo["completed"]:
        try:
            # Increment the existing user's count.
            todos_by_user[todo["userId"]] += 1
        except KeyError:
            # This user has not been seen. Set their count to 1.
            todos_by_user[todo["userId"]] = 1

# Create a sorted list of (userId, num_complete) pairs.
top_users = sorted(todos_by_user.items(), 
                   key=lambda x: x[1], reverse=True)

# Get the maximum number of complete TODOs.
max_complete = top_users[0][1]

# Create a list of all users who have completed
# the maximum number of TODOs.
users = []
for user, num_complete in top_users:
    if num_complete < max_complete:
        break
    users.append(str(user))

max_users = " and ".join(users)

# %%
s = "s" if len(users) > 1 else ""
print(f"user{s} {max_users} completed {max_complete} TODOs")
