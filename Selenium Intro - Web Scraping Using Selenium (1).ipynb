# %% [markdown]
# # Web Scraping Using Selenium
#
# The selenium package is used to automate web browser interaction from Python.

# %% [markdown]
# ## Installation
# While Selenium supports a number of browser engines, we will use Chrome for the following example, so please make sure you have the following packages installed:
#
# Chrome download page: https://www.google.com/chrome/
#
# A ChromeDriver binary matching your Chrome version: https://chromedriver.chromium.org/downloads

# %%
# pip install selenium

# %%
#!pip install selenium webdriver-manager

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Set up Chrome options
options = Options()
options.add_argument('--headless')  # Uncomment if you don't need the browser window
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# Automatically download the matching ChromeDriver
service = Service(ChromeDriverManager().install())

# Start the browser
driver = webdriver.Chrome(service=service, options=options)


# Example: Open a page
driver.get("https://www.google.com/")
print(driver.title)

# Close when done
driver.quit()
# Out:
# Google

# %% [markdown]
# Once you have downloaded, both, Chrome and ChromeDriver and installed the Selenium package, you should be ready to start the browser:

# %% [markdown]
# Running the browser from Selenium the way we just did is particularly helpful during development. It allows you observe exactly what's going on and how the page and the browser is behaving in the context of your code. Once you are happy with everything, it is generally advisable, however, to switch to said headless mode in production.
#
# In that mode, Selenium will start Chrome in the "background" without any visual output or windows. Fortunately, enabling headless mode only takes a few flags.

# %% [markdown]
# We only need to instantiate an *Options* object, set its headless field to True, and pass it to our WebDriver constructor. Done.

# %% [markdown]
# ### WebDriver Page Properties
#
# Building on our headless mode example.

# %%
driver = webdriver.Chrome(service=service, options=options)
driver.get("https://www.csueastbay.edu/futurestudents/index.html")
print(driver.page_source)
# Out:
# <html lang="en"><head>
#         <meta content="IE=edge" http-equiv="X-UA-Compatible">
#         <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
#         <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport">
#         <meta content="Prospective and future freshmen and transfer students can learn more about Cal State East Bay and what it has to offer, including housing, admission information, financial aid, cost of attendance and more. " name="description">
#         <title>Future Students - Cal State East Bay</title>
#         <!--BEGIN:GLOBAL-SCRIPTS-HEAD-->
#
#
#
# <link href="https://www.csueastbay.edu/_global/bootstrap/css/bootstrap.min.css" rel="stylesheet"><link href="https://www.csueastbay.edu/_global/bootstrap/css/bootstrap-accessibility.css" rel="stylesheet"><link href="https://www.csueastbay.edu/_global/font-awesome/css/font-awesome.min.css" rel="stylesheet"><link href="https://www.csueastbay.edu/_global/css/styles.css?v=36" rel="stylesheet"><link href="https://www.csueastbay.edu/_global/css/styles2.css" rel="stylesheet"><link href="https://www.csueastbay.edu/_global/css/flexslider.css?v=3" rel="stylesheet"><link href="https://www.csueastbay.edu/_global/css/slick.css?v=3" rel="stylesheet"><link href="https://www.csueastbay.edu/_global/css/magnific-pop.css" rel="stylesheet"><link href="//fonts.googleapis.com/css?family=Oswald:700" rel="stylesheet"><link href="https://fonts.googleapis.com/css?family=Libre+Baskerville" rel="stylesheet"><link href="https://www.csueastbay.edu/_global/css/vpm-styles.css" rel="stylesheet"><link href="https://www.csueastbay.edu/_global/css/widget-api.css" rel="stylesheet"><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_935b0d03.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTVjODQ0NGI5MA.js" data-id="C6P4J1C8D8G7TBKFGFT0"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTVjODQ0NGI5MA.js" data-id="C6P4J1C8D8G7TBKFGFT0"></script><script type="text/javascript" src="https://a2.adform.net/Serving/TrackPoint/?pm=2812111&amp;ADFdivider=%7C&amp;ord=760750532431&amp;ADFtpmode=2&amp;loc=https%3A%2F%2Fwww.csueastbay.edu%2Ffuturestudents%2Findex.html&amp;Set1=en-US%7Cen-US%7C1536x864%7C30"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/destination?id=AW-11350463599&amp;l=dataLayer&amp;cx=c&amp;gtm=45je53l1v870098967za200zb831295116&amp;tag_exp=102482433~102788824~102803279~102813109~102887799"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/destination?id=DC-10227059&amp;l=dataLayer&amp;cx=c&amp;gtm=45je53l1v870098967za200zb831295116&amp;tag_exp=102482433~102788824~102803279~102813109~102887799"></script><script type="text/javascript" async="" src="https://s2.adform.net/banners/scripts/st/trackpoint-async.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/events.js?sdkid=C6P4J1C8D8G7TBKFGFT0&amp;lib=ttq"></script><script src="https://connect.facebook.net/signals/config/603860886952007?v=2.9.190&amp;r=stable&amp;domain=www.csueastbay.edu&amp;hme=c1f2cecb0bd2e60711f2156ceae0254b57f69ec526dbc6c13633615b2168eda4&amp;ex_m=71%2C124%2C109%2C113%2C62%2C4%2C102%2C70%2C16%2C98%2C90%2C51%2C55%2C178%2C181%2C193%2C189%2C190%2C192%2C29%2C103%2C53%2C78%2C191%2C173%2C176%2C186%2C187%2C194%2C135%2C41%2C199%2C196%2C197%2C34%2C148%2C15%2C50%2C203%2C202%2C137%2C18%2C40%2C1%2C43%2C66%2C67%2C68%2C72%2C94%2C17%2C14%2C97%2C93%2C92%2C110%2C52%2C112%2C39%2C111%2C30%2C95%2C26%2C174%2C177%2C145%2C87%2C57%2C85%2C33%2C74%2C0%2C96%2C32%2C28%2C83%2C84%2C89%2C47%2C46%2C88%2C37%2C11%2C12%2C13%2C6%2C7%2C25%2C22%2C23%2C58%2C63%2C65%2C76%2C54%2C104%2C27%2C77%2C9%2C8%2C81%2C48%2C21%2C106%2C105%2C107%2C99%2C10%2C20%2C3%2C38%2C75%2C19%2C5%2C91%2C82%2C44%2C35%2C86%2C244%2C171%2C122%2C160%2C153%2C2%2C36%2C64%2C42%2C108%2C45%2C80%2C69%2C114%2C61%2C60%2C31%2C100%2C59%2C56%2C49%2C79%2C73%2C24%2C101%2C115" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://c.amazon-adsystem.com/aat/amzn.js"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script type="text/javascript" async="" src="https://analytics.tiktok.com/i18n/pixel/sdk.js?sdkid=C6P4J1C8D8G7TBKFGFT0"></script><script type="text/javascript" async="" src="https://www.googletagmanager.co ...
#         <!--END:GLOBAL-SCRIPTS-HEAD-->
#         <!--[if lt IE 9]>
#         <script src="//oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
#         <script src="//oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js"></script>
#         <![endif]-->
#         <link href="./" rel="canonical"><meta content="article" property="og:type"><meta content="summary_large_image" name="twitter:card"><meta content="@csueastbay" name="twitter:site"><meta content="Future Students" property="og:title"><meta content="https://www.csueastbay.edu/news-center/images/csueb-campus.jpg" property="og:image"><meta content="https://www.csueastbay.edu/news-center/images/csueb-campus.jpg" name="twitter:image">
#
# <script type="text/javascript">
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-5386844-22', 'auto');
# ga('set', 'transport', 'beacon');
# ga('send', 'pageview');
# </script>
# <script src="https://www.csueastbay.edu/_global/js/ga-extra-v2.min.js?v=2" type="text/javascript"></script>
#
#
#         <!--Google Tag Manager--><!--End Google Tag Manager--><script>
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WP98H96');
# </script>
#
#     <style id="fit-vids-style">.fluid-width-video-wrapper{width:100%;position:relative;padding:0;}.fluid-width-video-wrapper iframe,.fluid-width-video-wrapper object,.fluid-width-video-wrapper embed {position:absolute;top:0;left:0;width:100%;height:100%;}</style><link href="https://service.force.com/embeddedservice/5.0/esw.min.css" type="text/css" rel="stylesheet"><script attributionsrc="" type="text/javascript" async="" src="https://www.googleadservices.com/pagead/conversion/11350463599/?random=1742858668516&amp;cv=11&amp;fst=1742858668516&amp;bg=ffffff&amp;guid=ON&amp;async=1&amp;gcl_ctr=1&amp;gtm=45be53l1v9166912529z8831295116za201zb870098967&amp;gcd=13l3l3l3l1l1&amp;dma=0&amp;tag_exp=102308675~102482433~102788824~102803279~102813109~102926061~102926327&amp;u_w=1536&amp;u_h=864&amp;url=https%3A%2F%2Fwww.csueastbay.edu%2Ffuturestudents%2Findex.html&amp;label=jOPkCMPBpOYYEO-oqaQq&amp;hn=www.googleadservices.com&amp;frm=0&amp;tiba=Future%20Students%20-%20Cal%20State%20East%20Bay&amp;value=0&amp;bttype=purchase&amp;npa=0&amp;pscdl=noapi&amp;auid=2053698547.1742858668&amp;uaa=x86&amp;uab=64&amp;uafvl=Chromium%3B134.0.6998.166%7CNot%253AA-Brand%3B24.0.0.0%7CGoogle%2520Chrome%3B134.0.6998.166&amp;uamb=0&amp;uam=&amp;uap=Windows&amp;uapv=10.0.0&amp;uaw=0&amp;fledge=1&amp;capi=1&amp;_tu=Cg&amp;rfmt=3&amp;fmt=4"></script><script src="https://www.youvisit.com/SmartScript/latest/smartscript.js?v=25.3.2"></script><style id="ee472689-5cfa-489c-b231-859a0f68b100" for_class="youvisit-embed">.youvisit-embed{
#             border: none;
# overflow: hidden;
# position: relative;
# frameborder: 0;
#
#         }</style></head>
#     <body class="landing">
#         <!-- Google Tag Manager (noscript) --><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WP98H96" style="display:none;visibility:hidden" title="Google Tag Manager" width="0"></iframe></noscript><!-- End Google Tag Manager (noscript) -->
#
#     <!-- Google Tag Manager (noscript) -->
#     <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WMB2VSS9" style="display:none;visibility:hidden" width="0"></iframe></noscript>
#     <!-- End Google Tag Manager (noscript) -->
#         <!--BEGIN:SKIP TO SECTION NAV-->
#         <div class="screenreader"><a href="#skipToTopNav" title="Skip to Main Site Navigation"><img alt="Top Navigation" height="1" src="https://www.csueastbay.edu/_global/images/pixel.gif" width="1"></a><a href="#skipToContent" title="Skip to Content"><img alt="Top Navigation" height="1" src="https://www.csueastbay.edu/_global/images/pixel.gif" width="1"></a><a href="#skipToFooter" title="Skip to Footer"><img alt="Top Navigation" height="1" src="https://www.csueastbay.edu/_global/images/pixel.gif" width="1"></a></div>
#         <!--END:SKIP TO SECTION NAV-->
#         <noindex>
#         <!-- BEGIN: Header -->
#         <header>
#           <!-- Navigation -->
#           <nav aria-label="Main Navigation" class="navbar navbar-custom navbar-fixed-top affix-top" id="main-nav">
#
#
#
#
#           <span id="skipToTopNav"></span>
#
#
#
# <div class="container"><div class="navbar-header page-scroll"><a class="navbar-brand page-scroll" href="/index.html"><img alt="California State University, East Bay Signature Mark" class="logo desktop" src="/_global/images/header/new-csueb-logo/csueb-logo.png"><img alt="California State University, East Bay" class="logo mobile" src="/_global/images/header/new-csueb-logo/csueb-logo.png"></a></div><div class="navbar navbar-default yamm"><div class="navbar-header"><button class="search-icon navbar-toggle search-link" data-target="#navbar-collapse-grid-search" data-toggle="collapse" type="button" id="ui-collapse-578"><span class="fa fa-search"><span>Search</span></span></button><button class="menu-bar navbar-toggle" data-target="#navbar-collapse-grid" data-toggle="collapse" type="button" id="ui-collapse-489"><span class="fa fa-bars"><span>Menu</span></span></button><button class="navbar-toggle navbar-give" onclick="window.location.href='https://www.csueastbay.edu/giving/index.html';" type="button"><span class="fa fa-gift"><span>Give</span></span></button></div><div class="navbar-collapse search-closed" id="navbar-collapse-grid-search"><ul class="nav navbar-nav"><li class="grid-menu"><div class="row"><div class="col-sm-12"><form action="//www.csueastbay.edu/search/" class="ada-hidden" method="get"><div><input name="col" type="hidden" value="7"><label class="sr-only" for="searchInput2">Search Our Site</label><input aria-label="Search Our Site" class="search-input cleardefault" id="searchInput2" maxlength="255" name="q" placeholder="Search Cal State East Bay..." title="Search Cal State East Bay..." type="text" value="Search Cal State East Bay..."><input class="search-btn" title="Search" type="submit" value="Search"><button class="close search-link" data-target="#navbar-collapse-grid-search" data-toggle="collapse" type="button" id="ui-collapse-528"><span aria-hidden="true">×</span></button></div></form></div></div></li></ul></div><div class="navbar-collapses collapse" id="navbar-collapse-grid"><ul class="nav navbar-nav"><li class="yamm-fw item1"><a href="https://www.csueastbay.edu/apply/index.html"><span aria-hidden="true" class="fa fa-pencil"></span><span class="menu-link">Apply</span></a></li><li class="yamm-fw item1"><a href="https://www.csueastbay.edu/giving/index.html"><span aria-hidden="true" class="fa fa-gift"></span><span class="menu-link">Give</span></a></li><li class="yamm-fw dropdown mega-dropdown"><a aria-controls="menu" aria-expanded="false" class="dropdown-toggle item1" href="javascript:;" onclick="toggleMenu();" role="button"><span aria-hidden="true" class="fa fa-bars"></span><span class="menu-link">Menu</span></a><ul class="dropdown-menu mega-dropdown-menu submenu"><li class="tools"><div class="row"><div class="col-sm-12"><a href="https://www.csueastbay.edu/mycsueb/"><span class="fa fa-laptop"></span>MyCSUEB</a><a href="https://canvas.csueastbay.edu/"><img alt="Canvas Icon" src="/_global/images/elements/canvas.png">Canvas</a><a href="https://library.csueastbay.edu/"><span class="fa fa-bank"></span>Library</a><a href="https://mail.google.com/a/horizon.csueastbay.edu"><span class="fa fa-envelope-o"></span>Email</a><a href="https://mycompass.csueastbay.edu"><span class="fa fa-laptop"></span>MyCompass</a><a href="https://cmsweb.cs.csueastbay.edu/psc/CEBPRDF/EMPLOYEE/SA/c/EB_FACULTY_DIRCT_FL.EB_FCLTY_DIR_FL.GBL"><span class="fa fa-user"></span>Directory</a></div></div></li><li class="grid-menu"><div class="row"><div class="col-sm-3"><div class="section-title"><a href="https://www.csueastbay.edu/about/index.html">About</a><a class="toggle item" data-toggle="dropdown" href="#item-About" aria-haspopup="true" aria-expanded="false"><span aria-hidden="false" class="fa fa-angle-down"><span>Expand About Menu</span></span></a></div><div class="hidden sub-column" id="item-About"><a href="https://www.csueastbay.edu/accessibility" target="_blank" title="Accessibility - This link will open in a new window.">Accessibility</a><a href="htt ...
#           </nav>
#         </header>
#         <!-- END: Header -->
#         </noindex>
#
#         <div class="flexslider main-slider" id="slider"><ul class="slides"><li style="background-image: url(&quot;files/images/future-students-banner.jpg&quot;); width: 100%; float: left; margin-right: -100%; position: relative; opacity: 1; display: block; z-index: 2;" class="flex-active-slide"><img alt="Cal State East Bay students sit in front of monument East Bay letters" src="https://www.csueastbay.edu/_global/images/elements/slider-spacer.png" draggable="false"></li></ul><div class="flex-caption"><h1 class="title">Future Students</h1></div><ol class="flex-control-nav flex-control-paging"></ol><ul class="flex-direction-nav"><li class="flex-nav-prev"><a class="flex-prev flex-disabled" href="#" tabindex="-1">Previous</a></li><li class="flex-nav-next"><a class="flex-next flex-disabled" href="#" tabindex="-1">Next</a></li></ul></div>
#         <div class="row landing-nav"><nav aria-label="College Nav" class="navbar navbar-custom navbar-college" id="landing-nav"><div class="container"><div class="navbar navbar-default yamm"><div class="navbar-collapse collapse" id="navbar-collapse-college"><ul class="nav navbar-nav main-landing"><li class="yamm-fw item1"><a href="https://www2.calstate.edu/apply" target="_blank" title="Apply - Future Students - This link will open in a new window.">Apply</a></li><li class="yamm-fw item1"><a href="upcoming-events.html" title="UPCOMING EVENTS - Future Students">UPCOMING EVENTS</a></li><li class="yamm-fw item1"><a href="files/docs/2024-viewbook-final4.pdf" target="_blank" title="Viewbook of Colleges - Future Students - This link will open in a new window.">Viewbook of Colleges</a></li><li class="yamm-fw item1"><a href="https://www.csueastbay.edu/espanol/index.html" title="Información en español - Future Students">Información en español</a></li></ul><ul class="nav navbar-nav sub-landing"><li class="yamm-fw dropdown mega-dropdown more"><a aria-label="More site links" class="dropdown-toggle item1" href="javascript:;" title="More Site Links"><span class="menu-link">More</span><span aria-hidden="false" class="fa fa-caret-down"></span></a><ul class="dropdown-menu-landing mega-dropdown-menu submenu"><li class="grid-menu"><div class="row"><div class="col-sm-3"><div class="section-title"><a href="index.html" title="Student Resources - More Site Links - Future Students">Student Resources</a><a class="toggle item" data-toggle="dropdown" href="#subitem-StudentResources" aria-haspopup="true" aria-expanded="false"><span aria-hidden="false" class="fa fa-angle-down"><span>Expand Student Resources Menu - Future Students</span></span></a></div><div class="hidden sub-column" id="subitem-StudentResources"><a href="https://www.csueastbay.edu/accessibility/index.html" title="Accessibility Services - Student Resources - More Site Links - Future Students">Accessibility Services</a><a href="financial-aid-reminders.html" title="Financial Aid Reminders - Student Resources - More Site Links - Future Students">Financial Aid Reminders</a><a href="financial-aid-workshops.html" title="Financial Aid Workshops - Student Resources - More Site Links - Future Students">Financial Aid Workshops</a><a href="https://www.csueastbay.edu/visit/what-can-we-help-you-with-today.html" title="Get Help Applying - Student Resources - More Site Links - Future Students">Get Help Applying</a><a href="student-outreach-counselors.html" title="Get Pre-admission Counseling - Student Resources - More Site Links - Future Students">Get Pre-admission Counseling</a><a href="majors/index.html" title="List of Undergraduate Degrees - Student Resources - More Site Links - Future Students">List of Undergraduate Degrees</a><a href="western-undergraduate-exchange-wue-program.html" title="Western Undergraduate Exchange (WUE) Program - Student Resources - More Site Links - Future Students">Western Undergraduate Exchange (WUE) Program</a></div></div><div class="col-sm-3"><div class="section-title"><a href="resources-for-counselors.html" title="Counselor Resources - More Site Links - Future Students">Counselor Resources</a><a class="toggle item" data-toggle="dropdown" href="#subitem-CounselorResources" aria-haspopup="true" aria-expanded="false"><span aria-hidden="false" class="fa fa-angle-down"><span>Expand Counselor Resources Menu - Future Students</span></span></a></div><div class="hidden sub-column" id="subitem-CounselorResources"><a href="https://www.csueastbay.edu/admissions/index.html" title="Admission Requirements - Counselor Resources - More Site Links - Future Students">Admission Requirements</a><a href="http://www.csueastbay.edu/visit" target="_blank" title="Campus Tours - Counselor Resources - More Site Links -Future Students - This link will open in a new window.">Campus Tours</a></div></div></div></li></ul></li></ul></div></div></div></nav></div>
#         <!-- BEGIN: Content -->
#         <span id="skipToContent"></span>
#
#
#                                                   <div class="row band text-center white-bg ">
#                <div class="container">
#                                                                                                       <h2 class="section-heading">
#                                           <span class="red">Find Yourself</span>
#                                           <span class="red">Here</span>
#                                 </h2>
#                     <div class="box message">
#                                   <p><span style="font-weight: 400;">For more than 60 years, Cal State East Bay has served the Bay Area and beyond, providing access to higher education for a diverse student body and advancing regional engagement. In recent years, the university and its many programs have been included in several state and national rankings. Learn more about joining the Pioneer family.&nbsp;</span></p>
#                           </div>
#                     <div class="msg-btns">
#                                                                         <a class="btn-primary " href="request-info.html" target="_self">Request Information</a>
#                         </div>
#                  </div>
#     </div>
#
#
#     <div class="row band white-bg columns full">
#         <div class="container">
#           <div class="col-md-12">
#
#                             <iframe scrolling="no" title="Launch Virtual Tour." alt="Launch Virtual Tour." class="youvisit-embed" id="virtualtour_iframe_0" src="https://cdn.youvisit.com/tour/Embed/immersiveIcon?v=25.3.2&amp;ab=&amp;inst=60134&amp;loc=143999&amp;pl=v&amp;index=0&amp;debug=&amp;titleshow=&amp;module=&amp;&amp;_sp=undefined&amp;stopid=289036&amp;pl=v&amp;uiclass=&amp;hover=1" style="width: 946px; max-width: 946px; min-width: 946px; height: 432px; max-height: 432px; min-height: 432px;"></iframe><br><br>
# <h2>Take these steps to get started as a Pioneer</h2>
# <p><span style="font-weight: 400;"><span>One of the best ways to get to know our campus is through the <a href="https://futurepioneers.csueastbay.edu/s/">Future Pioneers Portal</a>. This portal is your personalized, one stop shop to:</span> </span></p>
# <ul>
# <li>Learn more about your major and academic support;</li>
# <li>Hear from current students about what it’s like to be a Pioneer;</li>
# <li>Get information about financial aid and paying for college;</li>
# <li>Meet your Outreach Counselor who can help you with next steps in the admissions process; and</li>
# <li>Identifying your next steps!</li>
# </ul>
#                                                                 <div class="col-md-12 btn-cta">
#
#                                         <a href="https://futurepioneers.csueastbay.edu/s/" target="_self">Register for the Future Pioneer Portal!</a>
#
#                 </div>
#                       </div>
#       </div>
#     </div>
#
#
#
#
#
#
#     <div class="row band white-bg spotlight">
#
#     	                                                                                            <div class="container">
#
#
#
#
#
#         		<div class="col-md-4 info-box ">
#         			<a href="majors/index.html" target="_self">
#         				<img alt="Students work on drone" src="files/images/majors-fs.jpg">
#         				<div class="featured-link">Majors<span aria-hidden="true" class="fa fa-chevron-circle-right"></span></div>
#         			</a>
#         		</div>
#
#
#
#
#
#
#
#
#
#         		<div class="col-md-4 info-box ">
#         			<a href="https://www.csueastbay.edu/admissions/index.html" target="_self">
#         				<img alt="Student Administration building with yellow sunset" src="files/images/fs-admission.jpg">
#         				<div class="featured-link">Admission<span aria-hidden="true" class="fa fa-chevron-circle-right"></span></div>
#         			</a>
#         		</div>
#
#
#
#
#
#
#
#
#
#         		<div class="col-md-4 info-box ">
#         			<a href="https://www.csueastbay.edu/visit/campustours.html" target="_self">
#         				<img alt="Students being led around by a tour guide" src="files/images/fs-campus-tours.jpg">
#         				<div class="featured-link">Campus Tours<span aria-hidden="true" class="fa fa-chevron-circle-right"></span></div>
#         			</a>
#         		</div>
#
#
#         		                                    </div>
#
#
#
#     	                                                                                            <div class="container">
#
#
#
#
#
#
#
#
#
#         		<div class="col-md-4 info-box ">
#         			<a href="https://www.csueastbay.edu/housing/index.html" target="_self">
#         				<img alt="Pioneer Heights on-campus housing with bay in the background" src="files/images/fs-housing.jpg">
#         				<div class="featured-link">Housing<span aria-hidden="true" class="fa fa-chevron-circle-right"></span></div>
#         			</a>
#         		</div>
#
#
#
#
#
#
#
#
#
#
#
#
#         		<div class="col-md-4 info-box ">
#         			<a href="https://www.csueastbay.edu/financialaid/prospective-students1/cost-of-attendance.html" target="_self">
#         				<img alt="Two female students looking at laptop together" src="files/images/fs-financial-aid.jpg">
#         				<div class="featured-link">Cost of Attendance &amp; Financial Aid<span aria-hidden="true" class="fa fa-chevron-circle-right"></span></div>
#         			</a>
#         		</div>
#
#
#
#
#
#
#
#
#
#
#
#
#         		<div class="col-md-4 info-box ">
#         			<a href="https://www.csueastbay.edu/academics/index.html" target="_self">
#         				<img alt="Male student looking inquisitively in classroom" src="files/images/fs-academics.jpg">
#         				<div class="featured-link">Academics<span aria-hidden="true" class="fa fa-chevron-circle-right"></span></div>
#         			</a>
#         		</div>
#
#
#         		                                    </div>
#
#
#         	        	                </div>
#
#                     <div class="row band columns contact-us">
#         <div class="container">
#           <div class="columns col-md-12">
#               <div class="col-md-12">
#               <div class="container gray-bg">
#                 <div class="col-md-12">
#                   <h2>Contact Us</h2>
#                 </div>
#                 <div class="col-md-4">
#                     <div class="gray-header-accent">The Welcome Center</div>
#                     <ul>
#                                             <li>25800 Carlos Bee Blvd</li>
#                                                                 <li>Student and Faculty Support Building, Suite 122</li>
#                                                                                                                                  <li>Hayward, CA 94542</li>
#                                         </ul>
#                     <ul>
#                                            <li>Phone: 510-885-2556 (Monday-Friday) </li>
#                                                                                   <li>Email: <a href="mailto:visit@csueastbay.edu">visit@csueastbay.edu</a></li>
#                                                                                     </ul>
#                 </div>
#                 <div class="col-md-8">
#                   <div class="masonry-layout">
#                                                                     <div class="masonry-layout-panel">
#                             <ul>
#                                                                                                                                                                                                     </ul>
#                         </div>
#                                       </div>
#                 </div>
#
#                 <div class="col-md-12">
#                   <div class="col-sm-12 social">
#                     <ul class="list-inline social-buttons">
#                                                                                                                                             <li><a href="https://www.instagram.com/csueb/"><span class="fa fa-instagram"><span>Instagram</span></span></a></li>
#                                                                                                                                                                         <li><a href="https://twitter.com/CalStateEastBay"><span class="fa fa-twitter"><span>Twitter</span></span></a></li>
#                                                                                                                                                                         <li><a href="https://www.facebook.com/CalStateEastBay/"><span class="fa fa-facebook"><span>Facebook</span></span></a></li>
#                                                                                                                                                                         <li><a href="https://www.youtube.com/channel/UCObJlgPQsJITHxy7RftZY6g/featured"><span class="fa fa-youtube-play"><span>YouTube</span></span></a></li>
#                                                                         </ul>
#                   </div>
#                 </div>
#
#
#               </div>
#               </div>
#           </div>
#         </div>
#     </div>
#
#         <div class="row band infographics content-2 parallax-background text-center  auto  landing">
#         <div class="parallax-container">
#             <div class="parallax-image" style="background-image: url(files/images/fs-point-of-pride.jpg);"></div>
#         </div>
#         <div class="infographic overlay"></div>
#         <div class="container mobile">
#           <div class="flexslider info-slider">
#
#         <div class="flex-viewport" style="overflow: hidden; position: relative;"><ul class="slides" style="width: 600%; margin-left: 0px;">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     <li class="random" data-thumb-alt="" style="width: 0px; margin-right: 0px; float: left; display: block;">
#                     <div class="col-md-4 info-box">
#                         <!-- Image Example -->
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-user"></span>
#                             </div>
#                                                 <p>More than 60% of Cal State East Bay students are female.
# </p>
#                     </div>
#                   </li><li class="random" data-thumb-alt="" style="width: 0px; margin-right: 0px; float: left; display: block;">
#                     <div class="col-md-4 info-box">
#                         <!-- Image Example -->
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-graduation-cap"></span>
#                             </div>
#                                                 <p>Sixty-two percent of Cal State East Bay students are the first in their family to go to college.</p>
#                     </div>
#                   </li><li class="random flex-active-slide" data-thumb-alt="" style="width: 0px; margin-right: 0px; float: left; display: block;">
#                     <div class="col-md-4 info-box">
#                         <!-- Image Example -->
#                                                                                 <div class="info-icon">
#                                 <span class="fa fa-${awesomeIcon}"></span>
#                             </div>
#                                                 <p>Cal State East Bay has three campuses — Hayward, Concord and Oakland.</p>
#                     </div>
#                   </li></ul></div><ol class="flex-control-nav flex-control-paging"><li><a href="#" class="flex-active">1</a></li><li><a href="#">2</a></li><li><a href="#">3</a></li></ol></div>
#         </div>
#         <div class="container desktop">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-trophy"></span>
#                             </div>
#                                                 <p>Alumnus Gene Luen Yang (MS ’03, Education) was the recipient of a prestigious MacArthur Foundation “Genius Grant."</p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-book"></span>
#                             </div>
#                                                 <p>Cal State East Bay offers more than 40 high-quality continuing education degree and certificate programs for working professionals.
# </p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-flask"></span>
#                             </div>
#                                                 <p>At the Green Biome Institute, faculty and students are sequencing the genomes of the mysterious and disappearing plants that could benefit humans. </p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-usd"></span>
#                             </div>
#                                                 <p>Within the region, Cal State East Bay alumni influence more than $2.5 billion in industry activity.</p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                         <div class="info-icon">
#                                   <img alt="Campus In Action logo" src="https://www.csueastbay.edu/_points-of-pride/images/Campus_In_Action2.png">
#                                 </div>
#                                                 <p>Cal State East Bay is committed to promoting civic engagement among students and has signed a Campus Compact Civic Action Statement.</p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-globe"></span>
#                             </div>
#                                                 <p>Cal State East Bay was noted for its exceptionally diverse student body, ranking as one of the most diverse four-year public college on the U.S. mainland by the Chronicle of Higher Education.</p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-graduation-cap"></span>
#                             </div>
#                                                 <p>Sixty-two percent of Cal State East Bay students are the first in their family to go to college.</p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                 <div class="info-icon">
#                                 <span class="fa fa-trophy"></span>
#                             </div>
#                                                 <p>The Pioneers for H.O.P.E. program supports students facing homelessness, food insecurity, and other various crisis situations.</p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-trophy"></span>
#                             </div>
#                                                 <p>CSUEB has 15 athletic teams and competes in NCAA Division II.</p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-usd"></span>
#                             </div>
#                                                 <p>Cal State East Bay ranks #25 in CNBC’s Top 50 US Colleges that Pay off the Most.</p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-graduation-cap"></span>
#                             </div>
#                                                 <p>Cal State East Bay offers more than 40 high-quality continuing education degree and certificate programs for working professionals.
# </p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-globe"></span>
#                             </div>
#                                                 <p>CSUEB has won a HEED award from INSIGHT Into Diversity magazine for six straight years. The award honors universities that have shown exceptional commitment to diversity and inclusiveness.</p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-users"></span>
#                             </div>
#                                                 <p>More than 130,000 alumni contribute to the economic, social and cultural quality of life in the East Bay and beyond. </p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-user"></span>
#                             </div>
#                                                 <p>More than 60% of Cal State East Bay students are female.
# </p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-microphone"></span>
#                             </div>
#                                                 <p>The annual Cultural Awareness Month series gives recognition to specific communities represented at the university and includes well-known guest speakers from each of those communities. </p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-users"></span>
#                             </div>
#                                                 <p>Notable alumni include the late MLB Hall of Famer Joe Morgan, California Wellness Foundation President and CEO Judy Belk, Tony-winning actor James Iglehart and former CSU Chancellor Timothy P. White.</p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-university"></span>
#                             </div>
#                                                 <p>Cal State East Bay offers 48 bachelor's degrees, 56 minors, 34 master’s degrees, 23 credentials and certificates and one doctoral degree. </p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                         <div class="info-icon">
#                                   <img alt="Pioneers logo" src="https://www.csueastbay.edu/_points-of-pride/images/eb-pp2.png">
#                                 </div>
#                                                 <p>Cal State East Bay's 15 athletic teams compete within NCAA Division II.</p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-globe"></span>
#                             </div>
#                                                 <p>The Wall Street Journal recognizes CSUEB as a Top 10 college in the west for diversity.</p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-users"></span>
#                             </div>
#                                                 <p>Access and retention programs for transfer students, including Sankofa and GANAS, smooth the transition from community college and lead to higher student involvement and graduation rates. </p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                 <div class="info-icon">
#                                 <span class="fa fa-university"></span>
#                             </div>
#                                                 <p>Cal State East Bay has three campuses — Hayward, Concord and Oakland.</p>
#                         <!-- </a> -->
#                     </div><div class="col-md-4 info-box  random ">
#                                                                                                             <div class="info-icon">
#                                 <span class="fa fa-trophy"></span>
#                             </div>
# ...
#                             </div>
#                                                 <p>The Wall Street Journal recognizes CSUEB as a Top 10 college in the west for diversity.</p>
#                         <!-- </a> -->
#                     </div></div>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <style type="text/css">
#     .embeddedServiceHelpButton .helpButton .uiButton {
#         background-color: #d50032;
#         font-family: "Salesforce Sans", sans-serif;
#     }
#     .embeddedServiceHelpButton .helpButton .uiButton:focus {
#         outline: 1px solid #d50032;
#     }
#     @font-face {
#         font-family: 'Salesforce Sans';
#         src: url('https://c1.sfdcstatic.com/etc/clientlibs/sfdc-aem-master/clientlibs_base/fonts/SalesforceSans-Regular.woff') format('woff'),
#         url('https://c1.sfdcstatic.com/etc/clientlibs/sfdc-aem-master/clientlibs_base/fonts/SalesforceSans-Regular.ttf') format('truetype');
#     }
# </style>
#
# <script src="https://service.force.com/embeddedservice/5.0/esw.min.js" type="text/javascript"></script>
# <script type="text/javascript" id="" charset="">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","603860886952007");fbq("track","PageView");</script>
# <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=603860886952007&amp;ev=PageView&amp;noscript=1"></noscript>
#
# 	<script type="text/javascript" id="" charset="">!function(d,g,e){d.TiktokAnalyticsObject=e;var a=d[e]=d[e]||[];a.methods="page track identify instances debug on off once ready alias group enableCookie disableCookie".split(" ");a.setAndDefer=function(b,c){b[c]=function(){b.push([c].concat(Array.prototype.slice.call(arguments,0)))}};for(d=0;d<a.methods.length;d++)a.setAndDefer(a,a.methods[d]);a.instance=function(b){b=a._i[b]||[];for(var c=0;c<a.methods.length;c++)a.setAndDefer(b,a.methods[c]);return b};a.load=function(b,c){var f="https://analytics.tiktok.com/i18n/pixel/events.js";
# a._i=a._i||{};a._i[b]=[];a._i[b]._u=f;a._t=a._t||{};a._t[b]=+new Date;a._o=a._o||{};a._o[b]=c||{};c=document.createElement("script");c.type="text/javascript";c.async=!0;c.src=f+"?sdkid\x3d"+b+"\x26lib\x3d"+e;b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(c,b)};a.load("C6P4J1C8D8G7TBKFGFT0");a.page()}(window,document,"ttq");</script>
#
# <script type="text/javascript" id="" charset="">window._adftrack=Array.isArray(window._adftrack)?window._adftrack:window._adftrack?[window._adftrack]:[];window._adftrack.push({HttpHost:"a2.adform.net",pm:2812111});(function(){var a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src="https://s2.adform.net/banners/scripts/st/trackpoint-async.js";var b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)})();</script>
# <noscript>
#     <p style="margin:0;padding:0;border:0;">
#         <img src="https://a2.adform.net/Serving/TrackPoint/?pm=2812111" width="1" height="1" alt="">
#     </p>
# </noscript>
# <iframe height="0" width="0" style="display: none; visibility: hidden;"></iframe><script id="" text="" charset="" type="text/javascript" src="https://www.youvisit.com/tour/Embed/js3"></script>
# <script type="text/javascript">
#     var initESW = function(gslbBaseURL) {
#         embedded_svc.settings.displayHelpButton = true; //Or false
#         embedded_svc.settings.language = ''; //For example, enter 'en' or 'en-US'
#
#         //embedded_svc.settings.defaultMinimizedText = '...'; //(Defaults to Chat with an Expert)
#         //embedded_svc.settings.disabledMinimizedText = '...'; //(Defaults to Agent Offline)
#
#         //embedded_svc.settings.loadingText = ''; //(Defaults to Loading)
#         //embedded_svc.settings.storageDomain = 'yourdomain.com'; //(Sets the domain for your deployment so that visitors can navigate subdomains during a chat session)
#
#         // Settings for Chat
#         //embedded_svc.settings.directToButtonRouting = function(prechatFormData) {
#             // Dynamically changes the button ID based on what the visitor enters in the pre-chat form.
#             // Returns a valid button ID.
#         //};
#         //embedded_svc.settings.prepopulatedPrechatFields = {}; //Sets the auto-population of pre-chat form fields
#         //embedded_svc.settings.fallbackRouting = []; //An array of button IDs, user IDs, or userId_buttonId
#         //embedded_svc.settings.offlineSupportMinimizedText = '...'; //(Defaults to Contact Us)
#
#         embedded_svc.settings.enabledFeatures = ['LiveAgent'];
#         embedded_svc.settings.entryFeature = 'LiveAgent';
#
#         embedded_svc.init(
#             'https://csueastbay-compass.my.salesforce.com',
#             'https://mycompass.csueastbay.edu/',
#             gslbBaseURL,
#             '00Df4000004JQAd',
#             'Student_Outreach',
#             {
#                 baseLiveAgentContentURL: 'https://c.la1-core2.sfdc-lywfpd.salesforceliveagent.com/content',
#                 deploymentId: '572f40000005t7P',
#                 buttonId: '573f40000005sXH',
#                 baseLiveAgentURL: 'https://d.la1-core2.sfdc-lywfpd.salesforceliveagent.com/chat',
#                 eswLiveAgentDevName: 'EmbeddedServiceLiveAgent_Parent04If4000000GsQsEAK_171615a508c',
#                 isOfflineSupportEnabled: true
#             }
#         );
#     };
#
#     if (!window.embedded_svc) {
#         var s = document.createElement('script');
#         s.setAttribute('src', 'https://csueastbay-compass.my.salesforce.com/embeddedservice/5.0/esw.min.js');
#         s.onload = function() {
#             initESW(null);
#         };
#         document.body.appendChild(s);
#     } else {
#         initESW('https://service.force.com');
#     }
# </script><script id="common-script" type="text/javascript" src="https://service.force.com/embeddedservice/5.0/utils/common.min.js"></script>
#         <!-- END: Content -->
#         <noindex>
#         <!-- BEGIN: Footer -->
#         <span id="skipToFooter"></span>
#
#
#
# <div class="footer-top"><div class="row"><div class="container"><div class="col-md-2 col-sm-6"><ul><li class="main-link"><input aria-label="Additional Resources Section" checked="checked" title="Additional Resources" type="checkbox"><span class="arrow">&nbsp;</span><h3 class="footer-link">Additional Resources</h3><ul class="footer-collapse"><li><a href="https://cm.maxient.com/reportingform.php?CSUEastBay&amp;layout_id=40">Sexual Assault / Title IX</a></li><li><a href="https://www.csueastbay.edu/futurestudents/request-info.html">Request Information</a></li><li><a href="http://www.csueastbay.edu/students">Current Students</a></li><li><a href="http://www.csueastbay.edu/faculty/">Faculty</a></li><li><a href="http://www.csueastbay.edu/staff/">Staff</a></li><li><a href="http://www.csueastbay.edu/alumni/">Alumni &amp; Friends</a></li><li><a href="http://www.csueastbay.edu/accessibility">Accessibility</a></li></ul></li></ul></div><div class="col-md-2 col-sm-6"><ul><li class="main-link"><input aria-label="Campus Section" checked="checked" title="Campus" type="checkbox"><span class="arrow">&nbsp;</span><h3 class="footer-link">Campus</h3><ul class="footer-collapse"><li><a href="https://www.csueastbay.edu/futuredirections/index.html">Mission Statement</a></li><li><a href="http://library.csueastbay.edu/">Library</a></li><li><a href="http://www.csueastbay.edu/bookstore">Bookstore</a></li><li><a href="https://www.csueastbay.edu/aps/index.html">Academic Programs</a></li><li><a href="https://www.csueastbay.edu/futurestudents/files/docs/cal-state-east-bay-viewbook.pdf" target="_blank" title="Viewbook of Colleges- This link will open in a new window.">Viewbook of Colleges</a></li></ul></li></ul></div><div class="col-md-2 col-sm-6"><ul><li class="main-link"><input aria-label="Legal Section" checked="checked" title="Legal" type="checkbox"><span class="arrow">&nbsp;</span><h3 class="footer-link">Legal</h3><ul class="footer-collapse"><li><a href="/privacy/index.html">Privacy Statement</a></li><li><a href="https://www.csueastbay.edu/riskmanagement/emergency-management/index.html">Emergency Info</a></li><li><a href="https://www.csueastbay.edu/upd/files/docs/csueb-annual-security-report.pdf" target="_blank" title="Annual Security Report- This link will open in a new window.">Annual Security Report</a></li><li><a href="https://www.csueastbay.edu/upd/files/docs/csueb-campus-safety-plan.pdf" target="_blank" title="Campus Safety Plan- This link will open in a new window.">Campus Safety Plan</a></li><li><a href="https://www.csueastbay.edu/riskmanagement/complaint.html">Register a Complaint</a></li><li><a href="https://www.csueastbay.edu/administration/title-ix/docs/notice-of-non-discrimination-2024-25.pdf" target="_blank" title="Notice of Non-Discrimination and Retaliation Prohibition- This link will open in a new window.">Notice of Non-Discrimination and Retaliation Prohibition</a></li></ul></li></ul></div><div class="col-md-2 col-sm-6"><ul><li class="main-link"><input aria-label="Tools Section" checked="checked" title="Tools" type="checkbox"><span class="arrow">&nbsp;</span><h3 class="footer-link">Tools</h3><ul class="footer-collapse"><li><a href="http://www.csueastbay.edu/directory/" target="_blank" title="Contact Us- This link will open in a new window.">Contact Us</a></li><li><a href="http://www.csueastbay.edu/directorysearch">Directory</a></li><li><a href="https://www.csueastbay.edu/about/visitor-information/index.html">Maps &amp; Directions</a></li><li><a href="https://www.csueastbay.edu/about/career-opportunities.html">Career Opportunities</a></li></ul></li></ul></div></div><div class="footer-logo col-md-12 text-center"><a href="/index.html"><img alt="CSU East Bay" class="img-responsive img-centered" src="/_global/images/footer/new-csueb-logo/vp2-logo.png"></a><p>25800 Carlos Bee Boulevard  |  Hayward, CA 94542  |  510-885-3000</p></div></div></div><footer aria-label="Footer" role="contentinfo"><div class="row"><div class="container"><span class="co ...
#         <!-- END: Footer -->
#         </noindex>
#         <!--BEGIN:GLOBAL-SCRIPTS-END-->
#         <script src="https://www.csueastbay.edu/_global/bootstrap/js/bootstrap.min.js"></script><script src="https://www.csueastbay.edu/_global/bootstrap/js/bootstrap-accessibility.js"></script><script src="https://www.csueastbay.edu/_global/js/jquery.fitvids.js"></script><script src="//cdnjs.cloudflare.com/ajax/libs/jquery-easing/1.3/jquery.easing.min.js"></script><script src="https://www.csueastbay.edu/_global/js/jquery.flexslider.js"></script><script src="https://www.csueastbay.edu/_global/js/slick.min.js"></script><script src="https://www.csueastbay.edu/_global/js/jquery.magnific-popup.min.js"></script><script src="https://www.csueastbay.edu/_global/js/jquery.quickflip.min.js"></script><script src="https://www.csueastbay.edu/_global/js/bootstrap-tabcollapse.js"></script><script src="https://www.csueastbay.edu/_global/js/packery.pkgd.min.js"></script><script src="https://www.csueastbay.edu/_global/js/ondeck-gtm.js"></script><script src="https://up.pixel.ad/assets/up.js?um=1"></script><script type="text/javascript">
#             cntrUpTag.track('cntrData', '920b0e4f683ea4f2');
#         </script><script src="https://www.csueastbay.edu/_global/js/scripts.js?v=6"></script>
#         <!--END:GLOBAL-SCRIPTS-END-->
#         <script type="text/javascript">if (jQuery(".main-slider").length != 0) {
#                 // The slider being synced must be initialized first
#                 $('.main-slider').flexslider({
#                     animationLoop: true,
#                     useCSS: false,
#                     pauseOnHover: false,
#                     slideshow: true
#                 });
#             }
#             </script>
#
#
#
#
#
# <iframe height="0" width="0" src="https://10227059.fls.doubleclick.net/activityi;src=10227059;type=allvi0;cat=csuea0;ord=4061953353057;npa=0;auiddc=2053698547.1742858668;u1=https%3A%2F%2Fwww.csueastbay.edu%2Ffuturestudents%2Findex.html;ps=1;pcor=1833852156;uaa=x86;uab=64;uafvl=Chromium%3B134.0.6998.166%7CNot%253AA-Brand%3B24.0.0.0%7CGoogle%2520Chrome%3B134.0.6998.166;uamb=0;uam=;uap=Windows;uapv=10.0.0;uaw=0;pscdl=noapi;frm=0;_tu=KlA;gtm=45fe53l1v9188988623z8831295116za201zb870098967;gcd=13l3l3l3l1l1;dma=0;dc_fmt=1;tag_exp=102482433~102788824~102803279~102813109~102887800;epver=2;~oref=https%3A%2F%2Fwww.csueastbay.edu%2Ffuturestudents%2Findex.html?" style="display: none; visibility: hidden;"></iframe><iframe allow="join-ad-interest-group" data-tagging-id="DC-10227059/allvi0/csuea0+standard" data-load-time="1742858668480" height="0" width="0" src="https://td.doubleclick.net/td/fls/rul/activityi;fledge=1;src=10227059;type=allvi0;cat=csuea0;ord=4061953353057;npa=0;auiddc=2053698547.1742858668;u1=https%3A%2F%2Fwww.csueastbay.edu%2Ffuturestudents%2Findex.html;ps=1;pcor=1833852156;uaa=x86;uab=64;uafvl=Chromium%3B134.0.6998.166%7CNot%253AA-Brand%3B24.0.0.0%7CGoogle%2520Chrome%3B134.0.6998.166;uamb=0;uam=;uap=Windows;uapv=10.0.0;uaw=0;pscdl=noapi;frm=0;_tu=KlA;gtm=45fe53l1v9188988623z8831295116za201zb870098967;gcd=13l3l3l3l1l1;dma=0;dc_fmt=9;tag_exp=102482433~102788824~102803279~102813109~102887800;epver=2;~oref=https%3A%2F%2Fwww.csueastbay.edu%2Ffuturestudents%2Findex.html?" style="display: none; visibility: hidden;"></iframe><iframe allow="join-ad-interest-group" data-tagging-id="AW-11350463599/jOPkCMPBpOYYEO-oqaQq" data-load-time="1742858668529" height="0" width="0" src="https://td.doubleclick.net/td/rul/11350463599?random=1742858668516&amp;cv=11&amp;fst=1742858668516&amp;fmt=3&amp;bg=ffffff&amp;guid=ON&amp;async=1&amp;gcl_ctr=1&amp;gtm=45be53l1v9166912529z8831295116za201zb870098967&amp;gcd=13l3l3l3l1l1&amp;dma=0&amp;tag_exp=102308675~102482433~102788824~102803279~102813109~102926061~102926327&amp;u_w=1536&amp;u_h=864&amp;url=https%3A%2F%2Fwww.csueastbay.edu%2Ffuturestudents%2Findex.html&amp;label=jOPkCMPBpOYYEO-oqaQq&amp;hn=www.googleadservices.com&amp;frm=0&amp;tiba=Future%20Students%20-%20Cal%20State%20East%20Bay&amp;value=0&amp;bttype=purchase&amp;npa=0&amp;pscdl=noapi&amp;auid=2053698547.1742858668&amp;uaa=x86&amp;uab=64&amp;uafvl=Chromium%3B134.0.6998.166%7CNot%253AA-Brand%3B24.0.0.0%7CGoogle%2520Chrome%3B134.0.6998.166&amp;uamb=0&amp;uam=&amp;uap=Windows&amp;uapv=10.0.0&amp;uaw=0&amp;fledge=1&amp;capi=1&amp;_tu=Cg&amp;ct_cookie_present=0" style="display: none; visibility: hidden;"></iframe><script id="liveagent-esw-script" type="text/javascript" src="https://service.force.com/embeddedservice/5.0/client/liveagent.esw.min.js"></script><form id="fileUploadForm" enctype="multipart/form-data" method="post" target="fileUploadIframe"><input type="file" id="fileSelector" name="file" style="display: none;"><input name="filename" type="hidden"></form><iframe id="fileUploadIframe" name="fileUploadIframe" title="FileUploadFrame" style="display: none;"></iframe><iframe src="javascript:false" style="width: 0px; height: 0px; border: 0px; display: none !important;"></iframe><img alt="Youvisit Pixel" src="https://trck.youvisit.com/embed/60134/143999.png?embed_type=immersive&amp;w=946&amp;h=432&amp;top=1350&amp;left=53&amp;pagewidth=1021&amp;pageHeight=4222&amp;screenWidth=1536&amp;screenHeight=824&amp;hasImgtag=false&amp;embed=50257625328642270&amp;ab=null_6&amp;pageSessionId=95531f79-e426-459b-9498-afe96a65947e&amp;source=v" style="display: none;"><img alt="Youvisit Pixel" src="https://trck.youvisit.com/page/60134/143999.png?embed=50257625328642270&amp;pageSessionId=95531f79-e426-459b-9498-afe96a65947e&amp;source=vhost" style="display: none;"><iframe id="esw_storage_iframe" src="https://service.force.com/embeddedservice/5.0/esw.html?parent=https://www.csueastbay.edu/futurestudents/index.html" title="Live Chat Metadata" style="display: none; ...

# %%
print(driver.title)
# Out:
# Future Students - Cal State East Bay

# %% [markdown]
# ### Locating Elements
#
# WebDriver provides two main methods for finding elements.
#
# - find_element
# - find_elements
#
# They are pretty similar, with the difference that the former looks for one single element, which it returns, whereas the latter will return a list of all found elements. Check https://selenium-python.readthedocs.io/locating-elements.html for more details.

# %%
driver.find_elements(By.TAG_NAME, 'p')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.26")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.27")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.28")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.29")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.30")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.31")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.32")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.34")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.35")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.36")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.37")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.38")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.39")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.40")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.41")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.42")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.43")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.44")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.45")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.46")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.47")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.48")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.49")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.50")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.51")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.52")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.53")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="aed4e0d815c53b210fd882f96e65fed2", element="f.E83CF6A69B241E2BCBBB8DA3443EC5A2.d.BE8A4054CCEF57CC7FE6A657FFD6FBA9.e.54")>]

# %% [markdown]
# ### Selenium WebElement
# A WebElement is a Selenium object representing an HTML element.
#
# There are many actions that you can perform on those objects, here are the most useful:
#
# - Accessing the text of the element with the property *element.text*
# - Clicking the element with *element.click()*
# - Accessing an attribute with *element.get_attribute('class')
# - Sending text to an input with *element.send_keys('mypassword')

# %%
result = driver.find_element(By.TAG_NAME, 'p')
result_text = result.text
print ('element.text: {0}'.format(result_text))
# Out:
# element.text: For more than 60 years, Cal State East Bay has served the Bay Area and beyond, providing access to higher education for a diverse student body and advancing regional engagement. In recent years, the university and its many programs have been included in several state and national rankings. Learn more about joining the Pioneer family.

# %% [markdown]
# ## Full example
# Here is a full example using the Selenium API methods we just covered.

# %%
driver.get("https://news.ycombinator.com/login")

login = driver.find_element(By.XPATH,"//input").send_keys('yourusername')
password = driver.find_element(By.XPATH,"//input[@type='password']").send_keys('yourpassword')
submit = driver.find_element(By.XPATH,"//input[@value='login']").click()

# %% [markdown]
# Now there is one important thing that is missing here. How do we know if we are logged in?
#
# We could try a couple of things:
#
# - Check for an error message (like "Wrong password")
# - Check for one element on the page that is only displayed once logged in.
#
# So, we're going to check for the logout button. The logout button has the ID *logout* (easy)!

# %%
from selenium.common.exceptions import NoSuchElementException
# dont forget from selenium.common.exceptions import NoSuchElementException
try:
    logout_button = driver.find_element(By.ID,"logout")
    print('Successfully logged in')
except NoSuchElementException:
    print('Incorrect login/password')
# Out:
# Incorrect login/password

# %% [markdown]
# ### Taking screenshots
#
# The beauty of browser approaches, like Selenium, is that we do not only get the data and the DOM tree, but that - being a browser - it also properly and fully renders the whole page. This, of course, also allows for screenshots and Selenium comes fully prepared here.

# %%
driver.save_screenshot('screenshot.png')
# Out:
# True

# %% [markdown]
# Please, do note, a few things can still go wrong or need tweaking, when you take a screenshot with Selenium.
# - First, you have to make sure that the window size is set correctly.
# - Then, you need to make sure that every asynchronous HTTP call made by the frontend JavaScript code has finished, and that the page is fully rendered.

# %% [markdown]
# ### Waiting for an element to be present
# Dealing with a website that uses lots of JavaScript to render its content can be tricky.

# %% [markdown]
# That means, we can't just send a request and immediately scrape the data, but we may have to wait until JavaScript completed its work. There are typically two ways to approach that:
#
# - Use *time.sleep()* before taking the screenshot.
# - Employ a *WebDriverWait* object.

# %%
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

driver = webdriver.Chrome()
driver.get("https://www.espn.com/")
try:
    element = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.NAME, 'title'))
    )
finally:
    driver.quit()

# %% [markdown]
# This will wait until the element with the HTML ID mySuperId appears, or the timeout of ten seconds has been reached.
